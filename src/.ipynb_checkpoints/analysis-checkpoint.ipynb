# %%
# Import libraries and read in the csv that was created with the notebook "preprocessing_data.ipynb".
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from matplotlib.pyplot import figure

df = pd.read_csv('../data/preprocessed/preprocessed_data.csv')
# Out:
# /Users/theres/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         Crime ID       Month                  Reported by  \
# 0            NaN  2021-09-01  Metropolitan Police Service
# 1            NaN  2021-09-01  Metropolitan Police Service
# 2            NaN  2021-09-01  Metropolitan Police Service
# 3            NaN  2021-09-01  Metropolitan Police Service
# 4            NaN  2021-09-01  Metropolitan Police Service
# ...          ...         ...                          ...
# 1183956      NaN  2020-11-01     British Transport Police
# 1183957      NaN  2020-11-01     British Transport Police
# 1183958      NaN  2020-11-01     British Transport Police
# 1183959      NaN  2020-11-01     British Transport Police
# 1183960      NaN  2020-11-01     British Transport Police
#
#                         Falls within  Longitude   Latitude  \
# 0        Metropolitan Police Service   0.135866  51.587336
# 1        Metropolitan Police Service   0.140035  51.589112
# 2        Metropolitan Police Service   0.140192  51.582311
# 3        Metropolitan Police Service   0.134947  51.588063
# 4        Metropolitan Police Service   0.140192  51.582311
# ...                              ...        ...        ...
# 1183956     British Transport Police  -0.133463  51.489300
# 1183957     British Transport Police  -0.505346  51.339500
# 1183958     British Transport Police  -0.505346  51.339500
# 1183959     British Transport Police  -0.505346  51.339500
# 1183960     British Transport Police  -0.505346  51.339500
#
#                                   Location  LSOA code  \
# 0               On or near Gibbfield Close  E01000027
# 1               On or near Beansland Grove  E01000027
# 2                   On or near Hatch Grove  E01000027
# 3                    On or near Mead Grove  E01000027
# 4                   On or near Hatch Grove  E01000027
# ...                                    ...        ...
# 1183956    On or near Pimlico (Lu Station)  E01004741
# 1183957  On or near West Byfleet (Station)  E01031004
# 1183958  On or near West Byfleet (Station)  E01031004
# 1183959  On or near West Byfleet (Station)  E01031004
# 1183960  On or near West Byfleet (Station)  E01031004
#
#                          LSOA name                    Crime type  \
# 0        Barking and Dagenham 001A         Anti-social behaviour
# 1        Barking and Dagenham 001A         Anti-social behaviour
# 2        Barking and Dagenham 001A         Anti-social behaviour
# 3        Barking and Dagenham 001A         Anti-social behaviour
# 4        Barking and Dagenham 001A         Anti-social behaviour
# ...                            ...                           ...
# 1183956           Westminster 024F  Violence and sexual offences
# 1183957                Woking 002E                 Bicycle theft
# 1183958                Woking 002E                 Bicycle theft
# 1183959                Woking 002E                  Public order
# 1183960                Woking 002E                 Vehicle crime
#
#         Last outcome category  Context                          Location type  \
# 0                         NaN      NaN                              On Street
# 1                         NaN      NaN                              On Street
# 2                         NaN      NaN                              On Street
# 3                         NaN      NaN                              On Street
# 4                         NaN      NaN                              On Street
# ...                       ...      ...                                    ...
# 1183956                   NaN      NaN  On or near London Underground Station
# 1183957                   NaN      NaN     On or near Train Station/Tram Stop
# 1183958                   NaN      NaN     On or near Train Station/Tram Stop
# 1183959                   NaN      NaN     On or near Train Station/Tram Stop
# 1183960                   NaN      NaN     On or near Train Station/Tram Stop
#
#         Season
# 0         Fall
# 1         Fall
# 2         Fall
# 3         Fall
# 4         Fall
# ...        ...
# 1183956   Fall
# 1183957   Fall
# 1183958   Fall
# 1183959   Fall
# 1183960   Fall
#
# [1183961 rows x 14 columns]

# %%
# Analysis on crime types

# %%
# Create a pivot table showing the total number of crimes by month 
df_pivot_month = pd.pivot_table(df, values='Reported by' , index='Month', aggfunc='count')
df_pivot_month
# Out:
#             Reported by
# Month
# 2020-11-01        98176
# 2020-12-01        89064
# 2021-01-01        85566
# 2021-02-01        80650
# 2021-03-01        92350
# 2021-04-01        87758
# 2021-05-01        92831
# 2021-06-01        96351
# 2021-07-01        95744
# 2021-08-01        89509
# 2021-09-01        91171
# 2021-10-01        94263
# 2021-11-01        90528

# %%
# Calculate the average crime counts per month
df_pivot_month.mean()
# Out:
# Reported by    91073.923077
# dtype: float64

# %%
df_pivot_month.median()
# Out:
# Reported by    91171.0
# dtype: float64

# %%
df_pivot_month = df_pivot_month.reset_index()

# %%
# Import Matplot library to display plots.
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20,15)

# %%
# Create a bar chart of the numbers of crimes per month
plt.figure(figsize=(10,10))
plt.bar(df_pivot_month['Month'], df_pivot_month['Reported by'], Width =0.8)
plt.ylabel("# of Crimes")
plt.xlabel("Month")
plt.xticks(rotation=90)
plt.title("Bar plot of total crimes by Month")

plt.show()
# Out:
# <ipython-input-8-903a655b99d9>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.bar(df_pivot_month['Month'], df_pivot_month['Reported by'], Width =0.8)

# %%
# Create a pivot table showing the total number of crimes by crime type and month 
df_pivot_ct_month = pd.pivot_table(df, values='Reported by', index='Month', columns='Crime type',
                          aggfunc='count')
df_pivot_ct_month
# Out:
# Crime type  Anti-social behaviour  Bicycle theft  Burglary  \
# Month
# 2020-11-01                  33930           2079      5200
# 2020-12-01                  29438           1352      4761
# 2021-01-01                  33691           1076      4274
# 2021-02-01                  29210           1127      4048
# 2021-03-01                  30663           1677      4631
# 2021-04-01                  27186           1891      4141
# 2021-05-01                  26203           2124      4166
# 2021-06-01                  27708           2198      4234
# 2021-07-01                  26313           2306      4226
# 2021-08-01                  23406           2121      4316
# 2021-09-01                  21987           2321      4312
# 2021-10-01                  21087           2088      4684
# 2021-11-01                  18061           1791      4822
#
# Crime type  Criminal damage and arson  Drugs  Other crime  Other theft  \
# Month
# 2020-11-01                       4336   4562          985         5828
# 2020-12-01                       4216   3783          782         6435
# 2021-01-01                       3738   3827          744         4889
# 2021-02-01                       3675   4184          756         4662
# 2021-03-01                       4334   4371          916         5335
# 2021-04-01                       4422   3878          884         6178
# 2021-05-01                       4804   3530          952         6877
# 2021-06-01                       4994   3288          814         8259
# 2021-07-01                       4776   3330          900         8412
# 2021-08-01                       4632   3231          779         8255
# 2021-09-01                       4560   3010          866         9047
# 2021-10-01                       4664   3683          952         9483
# 2021-11-01                       4577   3675          865         9817
#
# Crime type  Possession of weapons  Public order  Robbery  Shoplifting  \
# Month
# 2020-11-01                    548          4489     2356         2863
# 2020-12-01                    415          4117     2060         2764
# 2021-01-01                    373          3622     1498         2140
# 2021-02-01                    405          3525     1362         2282
# 2021-03-01                    429          5148     1667         2521
# 2021-04-01                    361          5189     1747         2729
# 2021-05-01                    394          5736     1780         3057
# 2021-06-01                    416          6054     1910         3030
# 2021-07-01                    445          6324     1894         3062
# 2021-08-01                    408          5134     1927         3253
# 2021-09-01                    408          5424     2228         2790
# 2021-10-01                    448          5584     2256         3107
# 2021-11-01                    475          5215     2306         2996
#
# Crime type  Theft from the person  Vehicle crime  Violence and sexual offences
# Month
# 2020-11-01                   2786           9134                         19080
# 2020-12-01                   3293           7717                         17931
# 2021-01-01                   1733           7647                         16314
# 2021-02-01                   1651           7600                         16163
# 2021-03-01                   2277           8271                         20110
# 2021-04-01                   2673           7065                         19414
# 2021-05-01                   3366           7746                         22096
# 2021-06-01                   3102           8009                         22335
# 2021-07-01                   3411           7640                         22705
# 2021-08-01                   3344           8648                         20055
# 2021-09-01                   3638           8984                         21596
# 2021-10-01                   4837           9133                         22257
# 2021-11-01                   5028           9307                         21593

# %%
# Create a line chart showing the total number of crimes for each crime type by month

df_pivot_ct_month.plot()

plt.show()

# %%
# Show value counts per crime type
df['Crime type'].value_counts()
# Out:
# Anti-social behaviour           348883
# Violence and sexual offences    261649
# Vehicle crime                   106901
# Other theft                      93477
# Public order                     65561
# Burglary                         57815
# Criminal damage and arson        57728
# Drugs                            48352
# Theft from the person            41139
# Shoplifting                      36594
# Robbery                          24991
# Bicycle theft                    24151
# Other crime                      11195
# Possession of weapons             5525
# Name: Crime type, dtype: int64

# %%
# Show value counts per crime type in percentage
df['Crime type'].value_counts(normalize = True)
# Out:
# Anti-social behaviour           0.294674
# Violence and sexual offences    0.220995
# Vehicle crime                   0.090291
# Other theft                     0.078953
# Public order                    0.055374
# Burglary                        0.048832
# Criminal damage and arson       0.048758
# Drugs                           0.040839
# Theft from the person           0.034747
# Shoplifting                     0.030908
# Robbery                         0.021108
# Bicycle theft                   0.020398
# Other crime                     0.009456
# Possession of weapons           0.004667
# Name: Crime type, dtype: float64

# %%
# Create labels for pie chart on crime types
crime = ['Anti-social behaviour (29.5%)','Violence and sexual offences (22.1%)','Vehicle crime (9.0%)','Other theft (7.9%)','Public order (5.5%)','Burglary (4.9%)','Criminal damage and arson (4.9%)','Drugs (4.1%)','Theft from the person (3.5%)','Shoplifting (3.1%)','Robbery(2.1%)','Bicycle theft (2.0%)','Other crime (0.9%)','Possession of weapons (0.5%)']

# %%
# Plot a pie chart on crime types
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True

labels = crime
sizes =  df['Crime type'].value_counts()

patches, texts = plt.pie(sizes, shadow=True, startangle=90)
plt.legend(patches,labels,bbox_to_anchor=(0.9, 1), loc=2, borderaxespad=0.)
plt.axis('equal')

plt.show()

# %%
# Create a table of crime counts by season
season_pivot = pd.pivot_table(df, values='Reported by', index='Season', aggfunc='count')
season_pivot
# Out:
#         Reported by
# Season
# Fall         283610
# Spring       272939
# Summer       281604
# Winter       255280

# %%
# Order the seasons correctly from Spring to Winter
season_pivot = season_pivot.reindex(index=['Spring','Summer','Fall','Winter'])
season_pivot
# Out:
#         Reported by
# Season
# Spring       272939
# Summer       281604
# Fall         283610
# Winter       255280

# %%
# Create a bar plot of crime counts by season
season_pivot = season_pivot.reset_index()
plt.figure(figsize=(10,10))
plt.bar(season_pivot['Season'], season_pivot['Reported by'], Width =0.8)
plt.ylabel("# of Crimes")
plt.xlabel("Season")
plt.title("Bar plot of total crimes by season")

plt.show()
# Out:
# <ipython-input-17-36451f0064cd>:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.bar(season_pivot['Season'], season_pivot['Reported by'], Width =0.8)

# %%
# Create a pivot table of crime types aggregated by season and directly order the seasons correctly.
df_pivot_crime = pd.pivot_table(df, values='Reported by', index='Season', columns='Crime type', aggfunc='count')
df_pivot_crime = df_pivot_crime.reindex(index=['Spring','Summer','Fall','Winter'])
df_pivot_crime
# Out:
# Crime type  Anti-social behaviour  Bicycle theft  Burglary  \
# Season
# Spring                      84052           5692     12938
# Summer                      77427           6625     12776
# Fall                        77004           6488     14196
# Winter                      92339           3555     13083
#
# Crime type  Criminal damage and arson  Drugs  Other crime  Other theft  \
# Season
# Spring                          13560  11779         2752        18390
# Summer                          14402   9849         2493        24926
# Fall                            13560  11255         2803        24358
# Winter                          11629  11794         2282        15986
#
# Crime type  Possession of weapons  Public order  Robbery  Shoplifting  \
# Season
# Spring                       1184         16073     5194         8307
# Summer                       1269         17512     5731         9345
# Fall                         1404         15497     6840         8760
# Winter                       1193         11264     4920         7186
#
# Crime type  Theft from the person  Vehicle crime  Violence and sexual offences
# Season
# Spring                       8316          23082                         61620
# Summer                       9857          24297                         65095
# Fall                        11261          27251                         62933
# Winter                       6677          22964                         50408

# %%
# Import Matplot library to display plots.
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20,15)

# %%
# Create a line plot of crime types aggregated by season
df_pivot_crime.plot()

plt.show()

# %%
# Create a new table grouped by season and crime types
table_crime = df.groupby(by=['Season','Crime type']).count()
table_crime
# Out:
#                                      Crime ID  Month  Reported by  \
# Season Crime type
# Fall   Anti-social behaviour                0  77004        77004
#        Bicycle theft                     6147   6488         6488
#        Burglary                         14180  14196        14196
#        Criminal damage and arson        13220  13560        13560
#        Drugs                            10980  11255        11255
#        Other crime                       2763   2803         2803
#        Other theft                      23715  24358        24358
#        Possession of weapons             1334   1404         1404
#        Public order                     14551  15497        15497
#        Robbery                           6671   6840         6840
#        Shoplifting                       8632   8760         8760
#        Theft from the person            10425  11261        11261
#        Vehicle crime                    27156  27251        27251
#        Violence and sexual offences     61757  62933        62933
# Spring Anti-social behaviour                0  84052        84052
#        Bicycle theft                     5480   5692         5692
#        Burglary                         12929  12938        12938
#        Criminal damage and arson        13124  13560        13560
#        Drugs                            11376  11779        11779
#        Other crime                       2714   2752         2752
#        Other theft                      17993  18390        18390
#        Possession of weapons             1124   1184         1184
#        Public order                     15239  16073        16073
#        Robbery                           5057   5194         5194
#        Shoplifting                       8217   8307         8307
#        Theft from the person             7810   8316         8316
#        Vehicle crime                    23028  23082        23082
#        Violence and sexual offences     60651  61620        61620
# Summer Anti-social behaviour                0  77427        77427
#        Bicycle theft                     6279   6625         6625
#        Burglary                         12760  12776        12776
#        Criminal damage and arson        14047  14402        14402
#        Drugs                             9634   9849         9849
#        Other crime                       2444   2493         2493
#        Other theft                      24304  24926        24926
#        Possession of weapons             1226   1269         1269
#        Public order                     16439  17512        17512
#        Robbery                           5621   5731         5731
#        Shoplifting                       9236   9345         9345
#        Theft from the person             9190   9857         9857
#        Vehicle crime                    24211  24297        24297
#        Violence and sexual offences     63852  65095        65095
# Winter Anti-social behaviour                0  92339        92339
#        Bicycle theft                     3479   3555         3555
#        Burglary                         13069  13083        13083
#        Criminal damage and arson        11256  11629        11629
#        Drugs                            11351  11794        11794
#        Other crime                       2251   2282         2282
#        Other theft                      15678  15986        15986
#        Possession of weapons             1116   1193         1193
#        Public order                     10657  11264        11264
#        Robbery                           4773   4920         4920
#        Shoplifting                       7111   7186         7186
#        Theft from the person             6191   6677         6677
#        Vehicle crime                    22929  22964        22964
#        Violence and sexual offences     49759  50408        50408
#
#                                      Falls within  Longitude  Latitude  \
# Season Crime type
# Fall   Anti-social behaviour                77004      77004     77004
#        Bicycle theft                         6488       6488      6488
#        Burglary                             14196      14196     14196
#        Criminal damage and arson            13560      13560     13560
#        Drugs                                11255      11255     11255
#        Other crime                           2803       2803      2803
#        Other theft                          24358      24358     24358
#        Possession of weapons                 1404       1404      1404
#        Public order                         15497      15497     15497
#        Robbery                               6840       6840      6840
#        Shoplifting                           8760       8760      8760
#        Theft from the person                11261      11261     11261
#        Vehicle crime                        27251      27251     27251
#        Violence and sexual offences         62933      62933     62933
# Spring Anti-social behaviour                84052      84052     84052
#        Bicycle theft                         5692       5692      5692
#        Burglary                             12938      12938     12938
#        Criminal damage and arson            13560      13560     13560
#        Drugs                                11779      11779     11779
#        Other crime                           2752       2752      2752
#        Other theft                          18390      18390     18390
#        Possession of weapons                 1184       1184      1184
#        Public order                         16073      16073     16073
#        Robbery                               5194       5194      5194
#        Shoplifting                           8307       8307      8307
#        Theft from the person                 8316       8316      8316
#        Vehicle crime                        23082      23082     23082
#        Violence and sexual offences         61620      61620     61620
# Summer Anti-social behaviour                77427      77427     77427
#        Bicycle theft                         6625       6625      6625
#        Burglary                             12776      12776     12776
#        Criminal damage and arson            14402      14402     14402
#        Drugs                                 9849       9849      9849
#        Other crime                           2493       2493      2493
#        Other theft                          24926      24926     24926
#        Possession of weapons                 1269       1269      1269
#        Public order                         17512      17512     17512
#        Robbery                               5731       5731      5731
#        Shoplifting                           9345       9345      9345
#        Theft from the person                 9857       9857      9857
#        Vehicle crime                        24297      24297     24297
#        Violence and sexual offences         65095      65095     65095
# Winter Anti-social behaviour                92339      92339     92339
#        Bicycle theft                         3555       3555      3555
#        Burglary                             13083      13083     13083
#        Criminal damage and arson            11629      11629     11629
#        Drugs                                11794      11794     11794
#        Other crime                           2282       2282      2282
#        Other theft                          15986      15986     15986
#        Possession of weapons                 1193       1193      1193
#        Public order                         11264      11264     11264
#        Robbery                               4920       4920      4920
#        Shoplifting                           7186       7186      7186
#        Theft from the person                 6677       6677      6677
#        Vehicle crime                        22964      22964     22964
#        Violence and sexual offences         50408      50408     50408
#
#                                      Location  LSOA code  LSOA name  \
# Season Crime type
# Fall   Anti-social behaviour            77004      77004      77004
#        Bicycle theft                     6488       6488       6488
#        Burglary                         14196      14196      14196
#        Criminal damage and arson        13560      13560      13560
#        Drugs                            11255      11255      11255
#        Other crime                       2803       2803       2803
#        Other theft                      24358      24358      24358
#        Possession of weapons             1404       1404       1404
#        Public order                     15497      15497      15497
#        Robbery                           6840       6840       6840
#        Shoplifting                       8760       8760       8760
#        Theft from the person            11261      11261      11261
#        Vehicle crime                    27251      27251      27251
#        Violence and sexual offences     62933      62933      62933
# Spring Anti-social behaviour            84052      84052      84052
#        Bicycle theft                     5692       5692       5692
#        Burglary                         12938      12938      12938
#        Criminal damage and arson        13560      13560      13560
#        Drugs                            11779      11779      11779
#        Other crime                       2752       2752       2752
#        Other theft                      18390      18390      18390
#        Possession of weapons             1184       1184       1184
#        Public order                     16073      16073      16073
#        Robbery                           5194       5194       5194
#        Shoplifting                       8307       8307       8307
#        Theft from the person             8316       8316       8316
#        Vehicle crime                    23082      23082      23082
#        Violence and sexual offences     61620      61620      61620
# Summer Anti-social behaviour            77427      77427      77427
#        Bicycle theft                     6625       6625       6625
#        Burglary                         12776      12776      12776
#        Criminal damage and arson        14402      14402      14402
#        Drugs                             9849       9849       9849
#        Other crime                       2493       2493       2493
#        Other theft                      24926      24926      24926
#        Possession of weapons             1269       1269       1269
#        Public order                     17512      17512      17512
#        Robbery                           5731       5731       5731
#        Shoplifting                       9345       9345       9345
#        Theft from the person             9857       9857       9857
#        Vehicle crime                    24297      24297      24297
#        Violence and sexual offences     65095      65095      65095
# Winter Anti-social behaviour            92339      92339      92339
#        Bicycle theft                     3555       3555       3555
#        Burglary                         13083      13083      13083
#        Criminal damage and arson        11629      11629      11629
#        Drugs                            11794      11794      11794
#        Other crime                       2282       2282       2282
#        Other theft                      15986      15986      15986
#        Possession of weapons             1193       1193       1193
#        Public order                     11264      11264      11264
#        Robbery                           4920       4920       4920
#        Shoplifting                       7186       7186       7186
#        Theft from the person             6677       6677       6677
#        Vehicle crime                    22964      22964      22964
#        Violence and sexual offences     50408      50408      50408
#
#                                      Last outcome category  Context  \
# Season Crime type
# Fall   Anti-social behaviour                             0        0
#        Bicycle theft                                  6147        0
#        Burglary                                      14180        0
#        Criminal damage and arson                     13220        0
#        Drugs                                         10980        0
#        Other crime                                    2763        0
#        Other theft                                   23715        0
#        Possession of weapons                          1334        0
#        Public order                                  14551        0
#        Robbery                                        6671        0
#        Shoplifting                                    8632        0
#        Theft from the person                         10425        0
#        Vehicle crime                                 27156        0
#        Violence and sexual offences                  61757        0
# Spring Anti-social behaviour                             0        0
#        Bicycle theft                                  5480        0
#        Burglary                                      12929        0
#        Criminal damage and arson                     13124        0
#        Drugs                                         11376        0
#        Other crime                                    2714        0
#        Other theft                                   17993        0
#        Possession of weapons                          1124        0
#        Public order                                  15239        0
#        Robbery                                        5057        0
#        Shoplifting                                    8217        0
#        Theft from the person                          7810        0
#        Vehicle crime                                 23028        0
#        Violence and sexual offences                  60651        0
# Summer Anti-social behaviour                             0        0
#        Bicycle theft                                  6279        0
#        Burglary                                      12760        0
#        Criminal damage and arson                     14047        0
#        Drugs                                          9634        0
#        Other crime                                    2444        0
#        Other theft                                   24304        0
#        Possession of weapons                          1226        0
#        Public order                                  16439        0
#        Robbery                                        5621        0
#        Shoplifting                                    9236        0
#        Theft from the person                          9190        0
#        Vehicle crime                                 24211        0
#        Violence and sexual offences                  63852        0
# Winter Anti-social behaviour                             0        0
#        Bicycle theft                                  3479        0
#        Burglary                                      13069        0
#        Criminal damage and arson                     11256        0
#        Drugs                                         11351        0
#        Other crime                                    2251        0
#        Other theft                                   15678        0
#        Possession of weapons                          1116        0
#        Public order                                  10657        0
#        Robbery                                        4773        0
#        Shoplifting                                    7111        0
#        Theft from the person                          6191        0
#        Vehicle crime                                 22929        0
#        Violence and sexual offences                  49759        0
#
#                                      Location type
# Season Crime type
# Fall   Anti-social behaviour                 77004
#        Bicycle theft                          6488
#        Burglary                              14196
#        Criminal damage and arson             13560
#        Drugs                                 11255
#        Other crime                            2803
#        Other theft                           24358
#        Possession of weapons                  1404
#        Public order                          15497
#        Robbery                                6840
#        Shoplifting                            8760
#        Theft from the person                 11261
#        Vehicle crime                         27251
#        Violence and sexual offences          62933
# Spring Anti-social behaviour                 84052
#        Bicycle theft                          5692
#        Burglary                              12938
#        Criminal damage and arson             13560
#        Drugs                                 11779
#        Other crime                            2752
#        Other theft                           18390
#        Possession of weapons                  1184
#        Public order                          16073
#        Robbery                                5194
#        Shoplifting                            8307
#        Theft from the person                  8316
#        Vehicle crime                         23082
#        Violence and sexual offences          61620
# Summer Anti-social behaviour                 77427
#        Bicycle theft                          6625
#        Burglary                              12776
#        Criminal damage and arson             14402
#        Drugs                                  9849
#        Other crime                            2493
#        Other theft                           24926
#        Possession of weapons                  1269
#        Public order                          17512
#        Robbery                                5731
#        Shoplifting                            9345
#        Theft from the person                  9857
#        Vehicle crime                         24297
#        Violence and sexual offences          65095
# Winter Anti-social behaviour                 92339
#        Bicycle theft                          3555
#        Burglary                              13083
#        Criminal damage and arson             11629
#        Drugs                                 11794
#        Other crime                            2282
#        Other theft                           15986
#        Possession of weapons                  1193
#        Public order                          11264
#        Robbery                                4920
#        Shoplifting                            7186
#        Theft from the person                  6677
#        Vehicle crime                         22964
#        Violence and sexual offences          50408

# %%
# Group dataframe by crime type
crime_grp = df.groupby(['Crime type'])

# %%
# Show percantage of locations grouped by crime types
crime_grp['Location type'].value_counts(normalize=True).head(60)
# Out:
# Crime type                 Location type
# Anti-social behaviour      On Street                                         0.888848
#                            On or near Parking Area                           0.020680
#                            On or near Supermarket                            0.020250
#                            On or near Sports/Recreation Area                 0.014423
#                            On or near Petrol Station                         0.010218
#                            On or near Shopping Area                          0.009608
#                            On or near Underpass                              0.007676
#                            On or near Further/Higher Educational Building    0.004919
#                            On or near Theatre/Concert Hall                   0.004663
#                            On or near Nightclub                              0.004563
#                            On or near Police Station                         0.004360
#                            On or near Hospital                               0.002517
#                            On or near Conference/Exhibition Centre           0.002201
#                            On or near Park/Open Space                        0.002187
#                            On or near Bus/Coach Station                      0.001708
#                            On or near Airport/Airfield                       0.000843
#                            On or near Meridian Square                        0.000335
# Bicycle theft              On Street                                         0.745435
#                            On or near Supermarket                            0.051675
#                            On or near Train Station/Tram Stop                0.040288
#                            On or near Parking Area                           0.030723
#                            On or near Shopping Area                          0.029191
#                            On or near Further/Higher Educational Building    0.015486
#                            On or near Hospital                               0.011594
#                            On or near Nightclub                              0.011345
#                            On or near Sports/Recreation Area                 0.010724
#                            On or near Theatre/Concert Hall                   0.010517
#                            On or near Petrol Station                         0.010103
#                            On or near Underpass                              0.009979
#                            On or near Conference/Exhibition Centre           0.006170
#                            On or near London Underground Station             0.005673
#                            On or near Police Station                         0.003395
#                            On or near Bus/Coach Station                      0.003064
#                            On or near Park/Open Space                        0.002774
#                            On or near Meridian Square                        0.001822
#                            On or near Airport/Airfield                       0.000041
# Burglary                   On Street                                         0.894699
#                            On or near Supermarket                            0.021119
#                            On or near Parking Area                           0.018386
#                            On or near Sports/Recreation Area                 0.011520
#                            On or near Petrol Station                         0.010758
#                            On or near Shopping Area                          0.010067
#                            On or near Underpass                              0.005915
#                            On or near Nightclub                              0.005725
#                            On or near Further/Higher Educational Building    0.005500
#                            On or near Theatre/Concert Hall                   0.003996
#                            On or near Hospital                               0.003234
#                            On or near Police Station                         0.002525
#                            On or near Conference/Exhibition Centre           0.002179
#                            On or near Park/Open Space                        0.001851
#                            On or near Bus/Coach Station                      0.001159
#                            On or near Train Station/Tram Stop                0.000726
#                            On or near Meridian Square                        0.000346
#                            On or near London Underground Station             0.000259
#                            On or near Airport/Airfield                       0.000035
# Criminal damage and arson  On Street                                         0.842780
#                            On or near Supermarket                            0.024148
#                            On or near Train Station/Tram Stop                0.020874
#                            On or near Parking Area                           0.020752
#                            On or near Petrol Station                         0.014499
# Name: Location type, dtype: float64

# %%
# Analysing crime type violence and sexual offences
crime_grp['Location type'].value_counts(normalize=True).loc['Violence and sexual offences']
# Out:
# Location type
# On Street                                         0.851824
# On or near Supermarket                            0.025668
# On or near Parking Area                           0.020543
# On or near Sports/Recreation Area                 0.014172
# On or near Petrol Station                         0.012066
# On or near Shopping Area                          0.011974
# On or near Hospital                               0.010040
# On or near Train Station/Tram Stop                0.010036
# On or near Nightclub                              0.007911
# On or near Underpass                              0.007415
# On or near London Underground Station             0.007380
# On or near Police Station                         0.005599
# On or near Further/Higher Educational Building    0.005404
# On or near Theatre/Concert Hall                   0.003745
# On or near Conference/Exhibition Centre           0.001892
# On or near Park/Open Space                        0.001743
# On or near Bus/Coach Station                      0.001632
# On or near Meridian Square                        0.000669
# On or near Airport/Airfield                       0.000287
# Name: Location type, dtype: float64

# %%
# Analysis on location types

# %%
# Create a new table with locations and their total counts
location_type_counts = df['Location type'].value_counts().rename_axis('location').reset_index(name='counts')

# %%
location_type_counts.iloc[0:7]
# Out:
#                              location  counts
# 0                           On Street  977360
# 1              On or near Supermarket   40298
# 2             On or near Parking Area   29104
# 3            On or near Shopping Area   25116
# 4           On or near Petrol Station   18966
# 5   On or near Sports/Recreation Area   15864
# 6  On or near Train Station/Tram Stop   11754

# %%
# Show Top 7 locations for crimes
top_seven = location_type_counts.iloc[0:7]
ax = sns.barplot(x='location', y='counts', hue='location', data=top_seven, dodge=False)

plt.show()

# %%
# Show value counts per location type in percentage
df['Location type'].value_counts(normalize = True)
# Out:
# On Street                                         0.825500
# On or near Supermarket                            0.034037
# On or near Parking Area                           0.024582
# On or near Shopping Area                          0.021214
# On or near Petrol Station                         0.016019
# On or near Sports/Recreation Area                 0.013399
# On or near Train Station/Tram Stop                0.009928
# On or near Nightclub                              0.008889
# On or near Underpass                              0.008527
# On or near London Underground Station             0.006649
# On or near Further/Higher Educational Building    0.005828
# On or near Hospital                               0.005607
# On or near Police Station                         0.005480
# On or near Theatre/Concert Hall                   0.005351
# On or near Conference/Exhibition Centre           0.002471
# On or near Park/Open Space                        0.002090
# On or near Bus/Coach Station                      0.001910
# On or near Meridian Square                        0.001680
# On or near Airport/Airfield                       0.000841
# Name: Location type, dtype: float64

# %%
# Group dataframe by location type
loc_grp=df.groupby(['Location type'])

# %%
# Show percentage of crime types by location "On or near Parking Area"
loc_grp['Crime type'].value_counts(normalize=True).loc['On or near Parking Area']
# Out:
# Crime type
# Anti-social behaviour           0.247904
# Violence and sexual offences    0.184683
# Other theft                     0.100673
# Vehicle crime                   0.080607
# Shoplifting                     0.080264
# Public order                    0.057930
# Theft from the person           0.053807
# Drugs                           0.052364
# Criminal damage and arson       0.041163
# Burglary                        0.036524
# Robbery                         0.026319
# Bicycle theft                   0.025495
# Other crime                     0.007628
# Possession of weapons           0.004639
# Name: Crime type, dtype: float64

# %%
# Create a new table grouped by season and location types
table_location = df.groupby(by=['Season','Location type']).count()

# %%
table_location
# Out:
#                                                        Crime ID   Month  \
# Season Location type
# Fall   On Street                                         163813  232090
#        On or near Airport/Airfield                          206     257
#        On or near Bus/Coach Station                         440     580
#        On or near Conference/Exhibition Centre              545     724
#        On or near Further/Higher Educational Building      1383    1806
# ...                                                         ...     ...
# Winter On or near Sports/Recreation Area                   2051    3464
#        On or near Supermarket                              6788    8612
#        On or near Theatre/Concert Hall                      606     999
#        On or near Train Station/Tram Stop                     0    2074
#        On or near Underpass                                1306    2013
#
#                                                        Reported by  \
# Season Location type
# Fall   On Street                                            232090
#        On or near Airport/Airfield                             257
#        On or near Bus/Coach Station                            580
#        On or near Conference/Exhibition Centre                 724
#        On or near Further/Higher Educational Building         1806
# ...                                                            ...
# Winter On or near Sports/Recreation Area                      3464
#        On or near Supermarket                                 8612
#        On or near Theatre/Concert Hall                         999
#        On or near Train Station/Tram Stop                     2074
#        On or near Underpass                                   2013
#
#                                                        Falls within  \
# Season Location type
# Fall   On Street                                             232090
#        On or near Airport/Airfield                              257
#        On or near Bus/Coach Station                             580
#        On or near Conference/Exhibition Centre                  724
#        On or near Further/Higher Educational Building          1806
# ...                                                             ...
# Winter On or near Sports/Recreation Area                       3464
#        On or near Supermarket                                  8612
#        On or near Theatre/Concert Hall                          999
#        On or near Train Station/Tram Stop                      2074
#        On or near Underpass                                    2013
#
#                                                        Longitude  Latitude  \
# Season Location type
# Fall   On Street                                          232090    232090
#        On or near Airport/Airfield                           257       257
#        On or near Bus/Coach Station                          580       580
#        On or near Conference/Exhibition Centre               724       724
#        On or near Further/Higher Educational Building       1806      1806
# ...                                                          ...       ...
# Winter On or near Sports/Recreation Area                    3464      3464
#        On or near Supermarket                               8612      8612
#        On or near Theatre/Concert Hall                       999       999
#        On or near Train Station/Tram Stop                   2074      2074
#        On or near Underpass                                 2013      2013
#
#                                                        Location  LSOA code  \
# Season Location type
# Fall   On Street                                         232090     232090
#        On or near Airport/Airfield                          257        257
#        On or near Bus/Coach Station                         580        580
#        On or near Conference/Exhibition Centre              724        724
#        On or near Further/Higher Educational Building      1806       1806
# ...                                                         ...        ...
# Winter On or near Sports/Recreation Area                   3464       3464
#        On or near Supermarket                              8612       8612
#        On or near Theatre/Concert Hall                      999        999
#        On or near Train Station/Tram Stop                  2074       2074
#        On or near Underpass                                2013       2013
#
#                                                        LSOA name  Crime type  \
# Season Location type
# Fall   On Street                                          232090      232090
#        On or near Airport/Airfield                           257         257
#        On or near Bus/Coach Station                          580         580
#        On or near Conference/Exhibition Centre               724         724
#        On or near Further/Higher Educational Building       1806        1806
# ...                                                          ...         ...
# Winter On or near Sports/Recreation Area                    3464        3464
#        On or near Supermarket                               8612        8612
#        On or near Theatre/Concert Hall                       999         999
#        On or near Train Station/Tram Stop                   2074        2074
#        On or near Underpass                                 2013        2013
#
#                                                        Last outcome category  \
# Season Location type
# Fall   On Street                                                      163813
#        On or near Airport/Airfield                                       206
#        On or near Bus/Coach Station                                      440
#        On or near Conference/Exhibition Centre                           545
#        On or near Further/Higher Educational Building                   1383
# ...                                                                      ...
# Winter On or near Sports/Recreation Area                                2051
#        On or near Supermarket                                           6788
#        On or near Theatre/Concert Hall                                   606
#        On or near Train Station/Tram Stop                                  0
#        On or near Underpass                                             1306
#
#                                                        Context
# Season Location type
# Fall   On Street                                             0
#        On or near Airport/Airfield                           0
#        On or near Bus/Coach Station                          0
#        On or near Conference/Exhibition Centre               0
#        On or near Further/Higher Educational Building        0
# ...                                                        ...
# Winter On or near Sports/Recreation Area                     0
#        On or near Supermarket                                0
#        On or near Theatre/Concert Hall                       0
#        On or near Train Station/Tram Stop                    0
#        On or near Underpass                                  0
#
# [76 rows x 12 columns]

# %%
# Create a pivot table of crime locations aggregated by season and directly order the seasons correctly.
df_pivot_location = pd.pivot_table(df, values='Reported by', index='Season', columns='Location type', aggfunc='count')
df_pivot_location = df_pivot_location.reindex(index=['Spring','Summer','Fall','Winter'])
df_pivot_location
# Out:
# Location type  On Street  On or near Airport/Airfield  \
# Season
# Spring            227968                          198
# Summer            230072                          228
# Fall              232090                          257
# Winter            215255                          183
#
# Location type  On or near Bus/Coach Station  \
# Season
# Spring                                  487
# Summer                                  547
# Fall                                    580
# Winter                                  455
#
# Location type  On or near Conference/Exhibition Centre  \
# Season
# Spring                                             629
# Summer                                             696
# Fall                                               724
# Winter                                             642
#
# Location type  On or near Further/Higher Educational Building  \
# Season
# Spring                                                   1495
# Summer                                                   1600
# Fall                                                     1806
# Winter                                                   1314
#
# Location type  On or near Hospital  On or near London Underground Station  \
# Season
# Spring                        1621                                   1669
# Summer                        1597                                   1972
# Fall                          1555                                   2048
# Winter                        1287                                   1247
#
# Location type  On or near Meridian Square  On or near Nightclub  \
# Season
# Spring                                338                  1723
# Summer                                561                  3128
# Fall                                  631                  2990
# Winter                                221                  1356
#
# Location type  On or near Park/Open Space  On or near Parking Area  \
# Season
# Spring                                638                     6404
# Summer                                567                     7059
# Fall                                  597                     7083
# Winter                                513                     5992
#
# Location type  On or near Petrol Station  On or near Police Station  \
# Season
# Spring                              4365                       1485
# Summer                              4478                       1572
# Fall                                4622                       1580
# Winter                              3979                       1302
#
# Location type  On or near Shopping Area  On or near Sports/Recreation Area  \
# Season
# Spring                             5177                               3667
# Summer                             6934                               3791
# Fall                               6194                               3785
# Winter                             4372                               3464
#
# Location type  On or near Supermarket  On or near Theatre/Concert Hall  \
# Season
# Spring                           9217                             1177
# Summer                           9567                             1764
# Fall                             9818                             1702
# Winter                           8612                              999
#
# Location type  On or near Train Station/Tram Stop  On or near Underpass
# Season
# Spring                                       2476                  2205
# Summer                                       2962                  2509
# Fall                                         3027                  2521
# Winter                                       2074                  2013

# %%
# Import Matplot library to display plots.
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20,15)

# %%
# Create a line chart of crimes at different locations, sorted by seasons.
df_pivot_location.plot()
plt.legend(bbox_to_anchor=(0.797, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
# Create a stacked bar chart of above location types by season.
ax = df_pivot_location.plot.bar(stacked=True, figsize=(8,6))
ax.set_ylim(0,300000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Create a new dataframe that filters out location type "On Street" in order to see the distribution of the other location types better in charts.
df_filt=df.loc[~df['Location type'].str.contains('On Street')]
df_filt
# Out:
#                                                   Crime ID       Month  \
# 15       e8c950bdd3989c2f16866d175893b959884d26fef2d344...  2021-09-01
# 16       29fcb6659808379b735abb13c05cbc7c3b283f5b4f4da4...  2021-09-01
# 18       c653ee4dae48f2fba6ac7abb821976247dcf4b16e4e02d...  2021-09-01
# 34       37dcecab173bc9095a7e3678b04e9228e92a1544fcdf00...  2021-09-01
# 35       f317fb3d36fffcf1229ea6703445ffd6ffcf86b74b6190...  2021-09-01
# ...                                                    ...         ...
# 1183956                                                NaN  2020-11-01
# 1183957                                                NaN  2020-11-01
# 1183958                                                NaN  2020-11-01
# 1183959                                                NaN  2020-11-01
# 1183960                                                NaN  2020-11-01
#
#                          Reported by                 Falls within  Longitude  \
# 15       Metropolitan Police Service  Metropolitan Police Service   0.137065
# 16       Metropolitan Police Service  Metropolitan Police Service   0.137065
# 18       Metropolitan Police Service  Metropolitan Police Service   0.137065
# 34       Metropolitan Police Service  Metropolitan Police Service   0.135071
# 35       Metropolitan Police Service  Metropolitan Police Service   0.135071
# ...                              ...                          ...        ...
# 1183956     British Transport Police     British Transport Police  -0.133463
# 1183957     British Transport Police     British Transport Police  -0.505346
# 1183958     British Transport Police     British Transport Police  -0.505346
# 1183959     British Transport Police     British Transport Police  -0.505346
# 1183960     British Transport Police     British Transport Police  -0.505346
#
#           Latitude                           Location  LSOA code  \
# 15       51.583672          On or near Police Station  E01000027
# 16       51.583672          On or near Police Station  E01000027
# 18       51.583672          On or near Police Station  E01000027
# 34       51.581154       On or near Pedestrian Subway  E01000029
# 35       51.581154       On or near Pedestrian Subway  E01000029
# ...            ...                                ...        ...
# 1183956  51.489300    On or near Pimlico (Lu Station)  E01004741
# 1183957  51.339500  On or near West Byfleet (Station)  E01031004
# 1183958  51.339500  On or near West Byfleet (Station)  E01031004
# 1183959  51.339500  On or near West Byfleet (Station)  E01031004
# 1183960  51.339500  On or near West Byfleet (Station)  E01031004
#
#                          LSOA name                    Crime type  \
# 15       Barking and Dagenham 001A  Violence and sexual offences
# 16       Barking and Dagenham 001A  Violence and sexual offences
# 18       Barking and Dagenham 001A  Violence and sexual offences
# 34       Barking and Dagenham 001C     Criminal damage and arson
# 35       Barking and Dagenham 001C     Criminal damage and arson
# ...                            ...                           ...
# 1183956           Westminster 024F  Violence and sexual offences
# 1183957                Woking 002E                 Bicycle theft
# 1183958                Woking 002E                 Bicycle theft
# 1183959                Woking 002E                  Public order
# 1183960                Woking 002E                 Vehicle crime
#
#                                  Last outcome category  Context  \
# 15                                 Under investigation      NaN
# 16       Investigation complete; no suspect identified      NaN
# 18                                 Under investigation      NaN
# 34       Investigation complete; no suspect identified      NaN
# 35                                 Under investigation      NaN
# ...                                                ...      ...
# 1183956                                            NaN      NaN
# 1183957                                            NaN      NaN
# 1183958                                            NaN      NaN
# 1183959                                            NaN      NaN
# 1183960                                            NaN      NaN
#
#                                  Location type Season
# 15                   On or near Police Station   Fall
# 16                   On or near Police Station   Fall
# 18                   On or near Police Station   Fall
# 34                        On or near Underpass   Fall
# 35                        On or near Underpass   Fall
# ...                                        ...    ...
# 1183956  On or near London Underground Station   Fall
# 1183957     On or near Train Station/Tram Stop   Fall
# 1183958     On or near Train Station/Tram Stop   Fall
# 1183959     On or near Train Station/Tram Stop   Fall
# 1183960     On or near Train Station/Tram Stop   Fall
#
# [206601 rows x 14 columns]

# %%
# Create a new pivot table of crime locations aggregated by season with the filtered dataframe
df_pivot_location_filt = pd.pivot_table(df_filt, values='Reported by', index='Season', columns='Location type', aggfunc='count')
df_pivot_location_filt = df_pivot_location_filt.reindex(index=['Spring','Summer','Fall','Winter'])
df_pivot_location_filt
# Out:
# Location type  On or near Airport/Airfield  On or near Bus/Coach Station  \
# Season
# Spring                                 198                           487
# Summer                                 228                           547
# Fall                                   257                           580
# Winter                                 183                           455
#
# Location type  On or near Conference/Exhibition Centre  \
# Season
# Spring                                             629
# Summer                                             696
# Fall                                               724
# Winter                                             642
#
# Location type  On or near Further/Higher Educational Building  \
# Season
# Spring                                                   1495
# Summer                                                   1600
# Fall                                                     1806
# Winter                                                   1314
#
# Location type  On or near Hospital  On or near London Underground Station  \
# Season
# Spring                        1621                                   1669
# Summer                        1597                                   1972
# Fall                          1555                                   2048
# Winter                        1287                                   1247
#
# Location type  On or near Meridian Square  On or near Nightclub  \
# Season
# Spring                                338                  1723
# Summer                                561                  3128
# Fall                                  631                  2990
# Winter                                221                  1356
#
# Location type  On or near Park/Open Space  On or near Parking Area  \
# Season
# Spring                                638                     6404
# Summer                                567                     7059
# Fall                                  597                     7083
# Winter                                513                     5992
#
# Location type  On or near Petrol Station  On or near Police Station  \
# Season
# Spring                              4365                       1485
# Summer                              4478                       1572
# Fall                                4622                       1580
# Winter                              3979                       1302
#
# Location type  On or near Shopping Area  On or near Sports/Recreation Area  \
# Season
# Spring                             5177                               3667
# Summer                             6934                               3791
# Fall                               6194                               3785
# Winter                             4372                               3464
#
# Location type  On or near Supermarket  On or near Theatre/Concert Hall  \
# Season
# Spring                           9217                             1177
# Summer                           9567                             1764
# Fall                             9818                             1702
# Winter                           8612                              999
#
# Location type  On or near Train Station/Tram Stop  On or near Underpass
# Season
# Spring                                       2476                  2205
# Summer                                       2962                  2509
# Fall                                         3027                  2521
# Winter                                       2074                  2013

# %%
# Create another line chart of crimes at different locations, sorted by seasons. This time "On Street" is filtered out to better analyze the other location types.
df_pivot_location_filt.plot()
plt.legend(bbox_to_anchor=(0.797, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
# Create a pivot table of crime count by crime and location type
df_pivot_crime_loc = pd.pivot_table(df, values='Reported by', index='Location type', columns='Crime type', aggfunc='count')
df_pivot_crime_loc
# Out:
# Crime type                                      Anti-social behaviour  \
# Location type
# On Street                                                    310104.0
# On or near Airport/Airfield                                     294.0
# On or near Bus/Coach Station                                    596.0
# On or near Conference/Exhibition Centre                         768.0
# On or near Further/Higher Educational Building                 1716.0
# On or near Hospital                                             878.0
# On or near London Underground Station                             NaN
# On or near Meridian Square                                      117.0
# On or near Nightclub                                           1592.0
# On or near Park/Open Space                                      763.0
# On or near Parking Area                                        7215.0
# On or near Petrol Station                                      3565.0
# On or near Police Station                                      1521.0
# On or near Shopping Area                                       3352.0
# On or near Sports/Recreation Area                              5032.0
# On or near Supermarket                                         7065.0
# On or near Theatre/Concert Hall                                1627.0
# On or near Train Station/Tram Stop                                NaN
# On or near Underpass                                           2678.0
#
# Crime type                                      Bicycle theft  Burglary  \
# Location type
# On Street                                             18003.0   51727.0
# On or near Airport/Airfield                               1.0       2.0
# On or near Bus/Coach Station                             74.0      67.0
# On or near Conference/Exhibition Centre                 149.0     126.0
# On or near Further/Higher Educational Building          374.0     318.0
# On or near Hospital                                     280.0     187.0
# On or near London Underground Station                   137.0      15.0
# On or near Meridian Square                               44.0      20.0
# On or near Nightclub                                    274.0     331.0
# On or near Park/Open Space                               67.0     107.0
# On or near Parking Area                                 742.0    1063.0
# On or near Petrol Station                               244.0     622.0
# On or near Police Station                                82.0     146.0
# On or near Shopping Area                                705.0     582.0
# On or near Sports/Recreation Area                       259.0     666.0
# On or near Supermarket                                 1248.0    1221.0
# On or near Theatre/Concert Hall                         254.0     231.0
# On or near Train Station/Tram Stop                      973.0      42.0
# On or near Underpass                                    241.0     342.0
#
# Crime type                                      Criminal damage and arson  \
# Location type
# On Street                                                         48652.0
# On or near Airport/Airfield                                          11.0
# On or near Bus/Coach Station                                        104.0
# On or near Conference/Exhibition Centre                             100.0
# On or near Further/Higher Educational Building                      254.0
# On or near Hospital                                                 449.0
# On or near London Underground Station                               442.0
# On or near Meridian Square                                           13.0
# On or near Nightclub                                                369.0
# On or near Park/Open Space                                          101.0
# On or near Parking Area                                            1198.0
# On or near Petrol Station                                           837.0
# On or near Police Station                                           519.0
# On or near Shopping Area                                            657.0
# On or near Sports/Recreation Area                                   760.0
# On or near Supermarket                                             1394.0
# On or near Theatre/Concert Hall                                     213.0
# On or near Train Station/Tram Stop                                 1205.0
# On or near Underpass                                                450.0
#
# Crime type                                        Drugs  Other crime  \
# Location type
# On Street                                       39010.0       9443.0
# On or near Airport/Airfield                        16.0        265.0
# On or near Bus/Coach Station                      149.0         21.0
# On or near Conference/Exhibition Centre            86.0         19.0
# On or near Further/Higher Educational Building    308.0         41.0
# On or near Hospital                               144.0         52.0
# On or near London Underground Station             466.0         60.0
# On or near Meridian Square                         47.0         15.0
# On or near Nightclub                              567.0         48.0
# On or near Park/Open Space                        184.0         14.0
# On or near Parking Area                          1524.0        222.0
# On or near Petrol Station                         699.0        122.0
# On or near Police Station                         646.0         74.0
# On or near Shopping Area                          737.0        135.0
# On or near Sports/Recreation Area                 735.0        160.0
# On or near Supermarket                           1239.0        256.0
# On or near Theatre/Concert Hall                   300.0         42.0
# On or near Train Station/Tram Stop                968.0        115.0
# On or near Underpass                              527.0         91.0
#
# Crime type                                      Other theft  \
# Location type
# On Street                                           67012.0
# On or near Airport/Airfield                           232.0
# On or near Bus/Coach Station                          229.0
# On or near Conference/Exhibition Centre               337.0
# On or near Further/Higher Educational Building        717.0
# On or near Hospital                                   758.0
# On or near London Underground Station                 888.0
# On or near Meridian Square                            483.0
# On or near Nightclub                                 1822.0
# On or near Park/Open Space                            247.0
# On or near Parking Area                              2930.0
# On or near Petrol Station                            4319.0
# On or near Police Station                             413.0
# On or near Shopping Area                             3833.0
# On or near Sports/Recreation Area                    1065.0
# On or near Supermarket                               5052.0
# On or near Theatre/Concert Hall                       846.0
# On or near Train Station/Tram Stop                   1369.0
# On or near Underpass                                  925.0
#
# Crime type                                      Possession of weapons  \
# Location type
# On Street                                                      4349.0
# On or near Airport/Airfield                                       5.0
# On or near Bus/Coach Station                                     18.0
# On or near Conference/Exhibition Centre                          11.0
# On or near Further/Higher Educational Building                   41.0
# On or near Hospital                                              23.0
# On or near London Underground Station                            82.0
# On or near Meridian Square                                       14.0
# On or near Nightclub                                             58.0
# On or near Park/Open Space                                       17.0
# On or near Parking Area                                         135.0
# On or near Petrol Station                                       104.0
# On or near Police Station                                        59.0
# On or near Shopping Area                                         92.0
# On or near Sports/Recreation Area                                78.0
# On or near Supermarket                                          166.0
# On or near Theatre/Concert Hall                                  26.0
# On or near Train Station/Tram Stop                              190.0
# On or near Underpass                                             57.0
#
# Crime type                                      Public order  Robbery  \
# Location type
# On Street                                            49370.0  18984.0
# On or near Airport/Airfield                             46.0      2.0
# On or near Bus/Coach Station                           196.0     84.0
# On or near Conference/Exhibition Centre                172.0     83.0
# On or near Further/Higher Educational Building         421.0    200.0
# On or near Hospital                                    601.0     68.0
# On or near London Underground Station                 1569.0    254.0
# On or near Meridian Square                              66.0     43.0
# On or near Nightclub                                   618.0    488.0
# On or near Park/Open Space                             153.0     97.0
# On or near Parking Area                               1686.0    766.0
# On or near Petrol Station                             1227.0    391.0
# On or near Police Station                              841.0    110.0
# On or near Shopping Area                              1456.0    678.0
# On or near Sports/Recreation Area                      857.0    401.0
# On or near Supermarket                                3024.0   1298.0
# On or near Theatre/Concert Hall                        317.0    222.0
# On or near Train Station/Tram Stop                    2254.0    409.0
# On or near Underpass                                   687.0    413.0
#
# Crime type                                      Shoplifting  \
# Location type
# On Street                                           16884.0
# On or near Airport/Airfield                            19.0
# On or near Bus/Coach Station                           74.0
# On or near Conference/Exhibition Centre               162.0
# On or near Further/Higher Educational Building        233.0
# On or near Hospital                                    66.0
# On or near London Underground Station                  59.0
# On or near Meridian Square                            290.0
# On or near Nightclub                                  605.0
# On or near Park/Open Space                             54.0
# On or near Parking Area                              2336.0
# On or near Petrol Station                            2084.0
# On or near Police Station                             294.0
# On or near Shopping Area                             5184.0
# On or near Sports/Recreation Area                     347.0
# On or near Supermarket                               6929.0
# On or near Theatre/Concert Hall                       271.0
# On or near Train Station/Tram Stop                    394.0
# On or near Underpass                                  309.0
#
# Crime type                                      Theft from the person  \
# Location type
# On Street                                                     25159.0
# On or near Airport/Airfield                                      11.0
# On or near Bus/Coach Station                                    118.0
# On or near Conference/Exhibition Centre                         190.0
# On or near Further/Higher Educational Building                  446.0
# On or near Hospital                                             144.0
# On or near London Underground Station                          1817.0
# On or near Meridian Square                                      586.0
# On or near Nightclub                                           1417.0
# On or near Park/Open Space                                       67.0
# On or near Parking Area                                        1566.0
# On or near Petrol Station                                       353.0
# On or near Police Station                                       158.0
# On or near Shopping Area                                       3630.0
# On or near Sports/Recreation Area                               404.0
# On or near Supermarket                                         2641.0
# On or near Theatre/Concert Hall                                 718.0
# On or near Train Station/Tram Stop                             1075.0
# On or near Underpass                                            639.0
#
# Crime type                                      Vehicle crime  \
# Location type
# On Street                                             95784.0
# On or near Airport/Airfield                              17.0
# On or near Bus/Coach Station                            104.0
# On or near Conference/Exhibition Centre                 227.0
# On or near Further/Higher Educational Building          417.0
# On or near Hospital                                     361.0
# On or near London Underground Station                   152.0
# On or near Meridian Square                               76.0
# On or near Nightclub                                    265.0
# On or near Park/Open Space                              148.0
# On or near Parking Area                                2346.0
# On or near Petrol Station                              1242.0
# On or near Police Station                               160.0
# On or near Shopping Area                                942.0
# On or near Sports/Recreation Area                      1392.0
# On or near Supermarket                                 2049.0
# On or near Theatre/Concert Hall                         288.0
# On or near Train Station/Tram Stop                      134.0
# On or near Underpass                                    797.0
#
# Crime type                                      Violence and sexual offences
# Location type
# On Street                                                           222879.0
# On or near Airport/Airfield                                             75.0
# On or near Bus/Coach Station                                           427.0
# On or near Conference/Exhibition Centre                                495.0
# On or near Further/Higher Educational Building                        1414.0
# On or near Hospital                                                   2627.0
# On or near London Underground Station                                 1931.0
# On or near Meridian Square                                             175.0
# On or near Nightclub                                                  2070.0
# On or near Park/Open Space                                             456.0
# On or near Parking Area                                               5375.0
# On or near Petrol Station                                             3157.0
# On or near Police Station                                             1465.0
# On or near Shopping Area                                              3133.0
# On or near Sports/Recreation Area                                     3708.0
# On or near Supermarket                                                6716.0
# On or near Theatre/Concert Hall                                        980.0
# On or near Train Station/Tram Stop                                    2626.0
# On or near Underpass                                                  1940.0

# %%
# Create a stacked bar chart of crime types by location type.
ax = df_pivot_crime_loc.plot.bar(stacked=True, figsize=(15,20))
ax.set_ylim(0,1000000)

# %%
# Create a new pivot table with the filtered dataframe (without "On Street") of crime counts by crime and location type
df_pivot_crime_loc_filt = pd.pivot_table(df_filt, values='Reported by', index='Location type', columns='Crime type', aggfunc='count')
df_pivot_crime_loc_filt
# Out:
# Crime type                                      Anti-social behaviour  \
# Location type
# On or near Airport/Airfield                                     294.0
# On or near Bus/Coach Station                                    596.0
# On or near Conference/Exhibition Centre                         768.0
# On or near Further/Higher Educational Building                 1716.0
# On or near Hospital                                             878.0
# On or near London Underground Station                             NaN
# On or near Meridian Square                                      117.0
# On or near Nightclub                                           1592.0
# On or near Park/Open Space                                      763.0
# On or near Parking Area                                        7215.0
# On or near Petrol Station                                      3565.0
# On or near Police Station                                      1521.0
# On or near Shopping Area                                       3352.0
# On or near Sports/Recreation Area                              5032.0
# On or near Supermarket                                         7065.0
# On or near Theatre/Concert Hall                                1627.0
# On or near Train Station/Tram Stop                                NaN
# On or near Underpass                                           2678.0
#
# Crime type                                      Bicycle theft  Burglary  \
# Location type
# On or near Airport/Airfield                               1.0       2.0
# On or near Bus/Coach Station                             74.0      67.0
# On or near Conference/Exhibition Centre                 149.0     126.0
# On or near Further/Higher Educational Building          374.0     318.0
# On or near Hospital                                     280.0     187.0
# On or near London Underground Station                   137.0      15.0
# On or near Meridian Square                               44.0      20.0
# On or near Nightclub                                    274.0     331.0
# On or near Park/Open Space                               67.0     107.0
# On or near Parking Area                                 742.0    1063.0
# On or near Petrol Station                               244.0     622.0
# On or near Police Station                                82.0     146.0
# On or near Shopping Area                                705.0     582.0
# On or near Sports/Recreation Area                       259.0     666.0
# On or near Supermarket                                 1248.0    1221.0
# On or near Theatre/Concert Hall                         254.0     231.0
# On or near Train Station/Tram Stop                      973.0      42.0
# On or near Underpass                                    241.0     342.0
#
# Crime type                                      Criminal damage and arson  \
# Location type
# On or near Airport/Airfield                                          11.0
# On or near Bus/Coach Station                                        104.0
# On or near Conference/Exhibition Centre                             100.0
# On or near Further/Higher Educational Building                      254.0
# On or near Hospital                                                 449.0
# On or near London Underground Station                               442.0
# On or near Meridian Square                                           13.0
# On or near Nightclub                                                369.0
# On or near Park/Open Space                                          101.0
# On or near Parking Area                                            1198.0
# On or near Petrol Station                                           837.0
# On or near Police Station                                           519.0
# On or near Shopping Area                                            657.0
# On or near Sports/Recreation Area                                   760.0
# On or near Supermarket                                             1394.0
# On or near Theatre/Concert Hall                                     213.0
# On or near Train Station/Tram Stop                                 1205.0
# On or near Underpass                                                450.0
#
# Crime type                                       Drugs  Other crime  \
# Location type
# On or near Airport/Airfield                       16.0        265.0
# On or near Bus/Coach Station                     149.0         21.0
# On or near Conference/Exhibition Centre           86.0         19.0
# On or near Further/Higher Educational Building   308.0         41.0
# On or near Hospital                              144.0         52.0
# On or near London Underground Station            466.0         60.0
# On or near Meridian Square                        47.0         15.0
# On or near Nightclub                             567.0         48.0
# On or near Park/Open Space                       184.0         14.0
# On or near Parking Area                         1524.0        222.0
# On or near Petrol Station                        699.0        122.0
# On or near Police Station                        646.0         74.0
# On or near Shopping Area                         737.0        135.0
# On or near Sports/Recreation Area                735.0        160.0
# On or near Supermarket                          1239.0        256.0
# On or near Theatre/Concert Hall                  300.0         42.0
# On or near Train Station/Tram Stop               968.0        115.0
# On or near Underpass                             527.0         91.0
#
# Crime type                                      Other theft  \
# Location type
# On or near Airport/Airfield                           232.0
# On or near Bus/Coach Station                          229.0
# On or near Conference/Exhibition Centre               337.0
# On or near Further/Higher Educational Building        717.0
# On or near Hospital                                   758.0
# On or near London Underground Station                 888.0
# On or near Meridian Square                            483.0
# On or near Nightclub                                 1822.0
# On or near Park/Open Space                            247.0
# On or near Parking Area                              2930.0
# On or near Petrol Station                            4319.0
# On or near Police Station                             413.0
# On or near Shopping Area                             3833.0
# On or near Sports/Recreation Area                    1065.0
# On or near Supermarket                               5052.0
# On or near Theatre/Concert Hall                       846.0
# On or near Train Station/Tram Stop                   1369.0
# On or near Underpass                                  925.0
#
# Crime type                                      Possession of weapons  \
# Location type
# On or near Airport/Airfield                                       5.0
# On or near Bus/Coach Station                                     18.0
# On or near Conference/Exhibition Centre                          11.0
# On or near Further/Higher Educational Building                   41.0
# On or near Hospital                                              23.0
# On or near London Underground Station                            82.0
# On or near Meridian Square                                       14.0
# On or near Nightclub                                             58.0
# On or near Park/Open Space                                       17.0
# On or near Parking Area                                         135.0
# On or near Petrol Station                                       104.0
# On or near Police Station                                        59.0
# On or near Shopping Area                                         92.0
# On or near Sports/Recreation Area                                78.0
# On or near Supermarket                                          166.0
# On or near Theatre/Concert Hall                                  26.0
# On or near Train Station/Tram Stop                              190.0
# On or near Underpass                                             57.0
#
# Crime type                                      Public order  Robbery  \
# Location type
# On or near Airport/Airfield                             46.0      2.0
# On or near Bus/Coach Station                           196.0     84.0
# On or near Conference/Exhibition Centre                172.0     83.0
# On or near Further/Higher Educational Building         421.0    200.0
# On or near Hospital                                    601.0     68.0
# On or near London Underground Station                 1569.0    254.0
# On or near Meridian Square                              66.0     43.0
# On or near Nightclub                                   618.0    488.0
# On or near Park/Open Space                             153.0     97.0
# On or near Parking Area                               1686.0    766.0
# On or near Petrol Station                             1227.0    391.0
# On or near Police Station                              841.0    110.0
# On or near Shopping Area                              1456.0    678.0
# On or near Sports/Recreation Area                      857.0    401.0
# On or near Supermarket                                3024.0   1298.0
# On or near Theatre/Concert Hall                        317.0    222.0
# On or near Train Station/Tram Stop                    2254.0    409.0
# On or near Underpass                                   687.0    413.0
#
# Crime type                                      Shoplifting  \
# Location type
# On or near Airport/Airfield                            19.0
# On or near Bus/Coach Station                           74.0
# On or near Conference/Exhibition Centre               162.0
# On or near Further/Higher Educational Building        233.0
# On or near Hospital                                    66.0
# On or near London Underground Station                  59.0
# On or near Meridian Square                            290.0
# On or near Nightclub                                  605.0
# On or near Park/Open Space                             54.0
# On or near Parking Area                              2336.0
# On or near Petrol Station                            2084.0
# On or near Police Station                             294.0
# On or near Shopping Area                             5184.0
# On or near Sports/Recreation Area                     347.0
# On or near Supermarket                               6929.0
# On or near Theatre/Concert Hall                       271.0
# On or near Train Station/Tram Stop                    394.0
# On or near Underpass                                  309.0
#
# Crime type                                      Theft from the person  \
# Location type
# On or near Airport/Airfield                                      11.0
# On or near Bus/Coach Station                                    118.0
# On or near Conference/Exhibition Centre                         190.0
# On or near Further/Higher Educational Building                  446.0
# On or near Hospital                                             144.0
# On or near London Underground Station                          1817.0
# On or near Meridian Square                                      586.0
# On or near Nightclub                                           1417.0
# On or near Park/Open Space                                       67.0
# On or near Parking Area                                        1566.0
# On or near Petrol Station                                       353.0
# On or near Police Station                                       158.0
# On or near Shopping Area                                       3630.0
# On or near Sports/Recreation Area                               404.0
# On or near Supermarket                                         2641.0
# On or near Theatre/Concert Hall                                 718.0
# On or near Train Station/Tram Stop                             1075.0
# On or near Underpass                                            639.0
#
# Crime type                                      Vehicle crime  \
# Location type
# On or near Airport/Airfield                              17.0
# On or near Bus/Coach Station                            104.0
# On or near Conference/Exhibition Centre                 227.0
# On or near Further/Higher Educational Building          417.0
# On or near Hospital                                     361.0
# On or near London Underground Station                   152.0
# On or near Meridian Square                               76.0
# On or near Nightclub                                    265.0
# On or near Park/Open Space                              148.0
# On or near Parking Area                                2346.0
# On or near Petrol Station                              1242.0
# On or near Police Station                               160.0
# On or near Shopping Area                                942.0
# On or near Sports/Recreation Area                      1392.0
# On or near Supermarket                                 2049.0
# On or near Theatre/Concert Hall                         288.0
# On or near Train Station/Tram Stop                      134.0
# On or near Underpass                                    797.0
#
# Crime type                                      Violence and sexual offences
# Location type
# On or near Airport/Airfield                                             75.0
# On or near Bus/Coach Station                                           427.0
# On or near Conference/Exhibition Centre                                495.0
# On or near Further/Higher Educational Building                        1414.0
# On or near Hospital                                                   2627.0
# On or near London Underground Station                                 1931.0
# On or near Meridian Square                                             175.0
# On or near Nightclub                                                  2070.0
# On or near Park/Open Space                                             456.0
# On or near Parking Area                                               5375.0
# On or near Petrol Station                                             3157.0
# On or near Police Station                                             1465.0
# On or near Shopping Area                                              3133.0
# On or near Sports/Recreation Area                                     3708.0
# On or near Supermarket                                                6716.0
# On or near Theatre/Concert Hall                                        980.0
# On or near Train Station/Tram Stop                                    2626.0
# On or near Underpass                                                  1940.0

# %%
# Create a new stacked bar chart of crime types by location type.
ax = df_pivot_crime_loc_filt.plot.bar(stacked=True, figsize=(15,20))
ax.set_ylim(0,42000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Analysis on last outcome category

# %%
# Show how many crimes have a last outcome category
df['Last outcome category'].count()
# Out:
# 815452

# %%
# Create a pivot table wich shows how crime type and last outcome category are connected
df_pivot_outcome = pd.pivot_table(df, values='Reported by', index='Crime type', columns='Last outcome category', aggfunc='count')
df_pivot_outcome
# Out:
# Last outcome category         Action to be taken by another organisation  \
# Crime type
# Bicycle theft                                                        NaN
# Burglary                                                             NaN
# Criminal damage and arson                                            NaN
# Drugs                                                                NaN
# Other crime                                                          5.0
# Other theft                                                          2.0
# Possession of weapons                                                NaN
# Public order                                                         2.0
# Robbery                                                              NaN
# Shoplifting                                                          NaN
# Theft from the person                                                NaN
# Vehicle crime                                                        NaN
# Violence and sexual offences                                        11.0
#
# Last outcome category         Awaiting court outcome  \
# Crime type
# Bicycle theft                                  119.0
# Burglary                                      1220.0
# Criminal damage and arson                     1179.0
# Drugs                                         4009.0
# Other crime                                    501.0
# Other theft                                    270.0
# Possession of weapons                         1078.0
# Public order                                  1875.0
# Robbery                                        734.0
# Shoplifting                                   1238.0
# Theft from the person                          199.0
# Vehicle crime                                  482.0
# Violence and sexual offences                  5531.0
#
# Last outcome category         Court result unavailable  \
# Crime type
# Bicycle theft                                     71.0
# Burglary                                         823.0
# Criminal damage and arson                       1134.0
# Drugs                                           4219.0
# Other crime                                      536.0
# Other theft                                      204.0
# Possession of weapons                           1097.0
# Public order                                    1466.0
# Robbery                                          488.0
# Shoplifting                                     1148.0
# Theft from the person                             98.0
# Vehicle crime                                    441.0
# Violence and sexual offences                    4134.0
#
# Last outcome category         Formal action is not in the public interest  \
# Crime type
# Bicycle theft                                                         1.0
# Burglary                                                              1.0
# Criminal damage and arson                                             6.0
# Drugs                                                                49.0
# Other crime                                                           9.0
# Other theft                                                           5.0
# Possession of weapons                                                 7.0
# Public order                                                         27.0
# Robbery                                                               2.0
# Shoplifting                                                          20.0
# Theft from the person                                                 3.0
# Vehicle crime                                                         1.0
# Violence and sexual offences                                         20.0
#
# Last outcome category         Further investigation is not in the public interest  \
# Crime type
# Bicycle theft                                                               NaN
# Burglary                                                                    NaN
# Criminal damage and arson                                                   NaN
# Drugs                                                                       3.0
# Other crime                                                                 NaN
# Other theft                                                                 NaN
# Possession of weapons                                                       NaN
# Public order                                                                1.0
# Robbery                                                                     NaN
# Shoplifting                                                                 2.0
# Theft from the person                                                       NaN
# Vehicle crime                                                               NaN
# Violence and sexual offences                                                3.0
#
# Last outcome category         Investigation complete; no suspect identified  \
# Crime type
# Bicycle theft                                                       19136.0
# Burglary                                                            37154.0
# Criminal damage and arson                                           36333.0
# Drugs                                                                2356.0
# Other crime                                                          5084.0
# Other theft                                                         66585.0
# Possession of weapons                                                1050.0
# Public order                                                        29701.0
# Robbery                                                             11134.0
# Shoplifting                                                         21233.0
# Theft from the person                                               28473.0
# Vehicle crime                                                       91666.0
# Violence and sexual offences                                       123005.0
#
# Last outcome category         Local resolution  Offender given a caution  \
# Crime type
# Bicycle theft                             33.0                      23.0
# Burglary                                  33.0                      46.0
# Criminal damage and arson                815.0                     606.0
# Drugs                                  21959.0                    1729.0
# Other crime                              351.0                     134.0
# Other theft                              189.0                      91.0
# Possession of weapons                     67.0                     274.0
# Public order                             481.0                     291.0
# Robbery                                   18.0                      24.0
# Shoplifting                             1239.0                     146.0
# Theft from the person                     47.0                      21.0
# Vehicle crime                             35.0                      21.0
# Violence and sexual offences            2009.0                    2316.0
#
# Last outcome category         Offender given a drugs possession warning  \
# Crime type
# Bicycle theft                                                       NaN
# Burglary                                                            NaN
# Criminal damage and arson                                           NaN
# Drugs                                                             403.0
# Other crime                                                         NaN
# Other theft                                                         NaN
# Possession of weapons                                               NaN
# Public order                                                        NaN
# Robbery                                                             NaN
# Shoplifting                                                         NaN
# Theft from the person                                               NaN
# Vehicle crime                                                       NaN
# Violence and sexual offences                                        1.0
#
# Last outcome category         Offender given penalty notice  \
# Crime type
# Bicycle theft                                           NaN
# Burglary                                                2.0
# Criminal damage and arson                              84.0
# Drugs                                                5923.0
# Other crime                                             1.0
# Other theft                                             4.0
# Possession of weapons                                   2.0
# Public order                                          303.0
# Robbery                                                 1.0
# Shoplifting                                           222.0
# Theft from the person                                   4.0
# Vehicle crime                                           1.0
# Violence and sexual offences                           24.0
#
# Last outcome category         Status update unavailable  \
# Crime type
# Bicycle theft                                    1021.0
# Burglary                                         5608.0
# Criminal damage and arson                        6903.0
# Drugs                                            3276.0
# Other crime                                      2349.0
# Other theft                                      8227.0
# Possession of weapons                             826.0
# Public order                                    13562.0
# Robbery                                          4832.0
# Shoplifting                                      4141.0
# Theft from the person                            2683.0
# Vehicle crime                                    4047.0
# Violence and sexual offences                    57197.0
#
# Last outcome category         Suspect charged as part of another case  \
# Crime type
# Bicycle theft                                                     2.0
# Burglary                                                         29.0
# Criminal damage and arson                                         1.0
# Drugs                                                             NaN
# Other crime                                                       NaN
# Other theft                                                       NaN
# Possession of weapons                                             NaN
# Public order                                                      NaN
# Robbery                                                           NaN
# Shoplifting                                                       NaN
# Theft from the person                                             NaN
# Vehicle crime                                                     NaN
# Violence and sexual offences                                      NaN
#
# Last outcome category         Unable to prosecute suspect  Under investigation
# Crime type
# Bicycle theft                                         9.0               2626.0
# Burglary                                             15.0              12827.0
# Criminal damage and arson                            30.0               8990.0
# Drugs                                                18.0               2974.0
# Other crime                                           7.0               2043.0
# Other theft                                          17.0              15626.0
# Possession of weapons                                 3.0                849.0
# Public order                                         90.0              13939.0
# Robbery                                               9.0               7086.0
# Shoplifting                                          74.0               6678.0
# Theft from the person                                 6.0               6713.0
# Vehicle crime                                         3.0               9918.0
# Violence and sexual offences                        251.0              62590.0

# %%
# Create a stacked bar chart of the above last outcome category sorted by crime type.
ax = df_pivot_outcome.plot.bar(stacked=True, figsize=(15,20))
ax.set_ylim(0,270000)

# %%
# Show the value count of last outcome for Drugs in percentage
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Drugs']
# Out:
# Last outcome category
# Local resolution                                       0.468029
# Offender given penalty notice                          0.126242
# Court result unavailable                               0.089923
# Awaiting court outcome                                 0.085447
# Status update unavailable                              0.069824
# Under investigation                                    0.063387
# Investigation complete; no suspect identified          0.050215
# Offender given a caution                               0.036852
# Offender given a drugs possession warning              0.008589
# Formal action is not in the public interest            0.001044
# Unable to prosecute suspect                            0.000384
# Further investigation is not in the public interest    0.000064
# Name: Last outcome category, dtype: float64

# %%
# Show the value count of last outcome for Possession of weapons in percentage
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Possession of weapons']
# Out:
# Last outcome category
# Court result unavailable                         0.208833
# Awaiting court outcome                           0.205216
# Investigation complete; no suspect identified    0.199886
# Under investigation                              0.161622
# Status update unavailable                        0.157243
# Offender given a caution                         0.052161
# Local resolution                                 0.012755
# Formal action is not in the public interest      0.001333
# Unable to prosecute suspect                      0.000571
# Offender given penalty notice                    0.000381
# Name: Last outcome category, dtype: float64

# %%
# Create a table where data is grouped by crime types and the last outcome category
table = df.groupby(by=['Crime type','Last outcome category']).count()
table
# Out:
#                                                                             Crime ID  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                              119
#                              Court result unavailable                             71
#                              Formal action is not in the public interest           1
#                              Investigation complete; no suspect identified     19136
#                              Local resolution                                     33
# ...                                                                              ...
# Violence and sexual offences Offender given a drugs possession warning             1
#                              Offender given penalty notice                        24
#                              Status update unavailable                         57197
#                              Unable to prosecute suspect                         251
#                              Under investigation                               62590
#
#                                                                             Month  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                           119
#                              Court result unavailable                          71
#                              Formal action is not in the public interest        1
#                              Investigation complete; no suspect identified  19136
#                              Local resolution                                  33
# ...                                                                           ...
# Violence and sexual offences Offender given a drugs possession warning          1
#                              Offender given penalty notice                     24
#                              Status update unavailable                      57197
#                              Unable to prosecute suspect                      251
#                              Under investigation                            62590
#
#                                                                             Reported by  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                                 119
#                              Court result unavailable                                71
#                              Formal action is not in the public interest              1
#                              Investigation complete; no suspect identified        19136
#                              Local resolution                                        33
# ...                                                                                 ...
# Violence and sexual offences Offender given a drugs possession warning                1
#                              Offender given penalty notice                           24
#                              Status update unavailable                            57197
#                              Unable to prosecute suspect                            251
#                              Under investigation                                  62590
#
#                                                                             Falls within  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                                  119
#                              Court result unavailable                                 71
#                              Formal action is not in the public interest               1
#                              Investigation complete; no suspect identified         19136
#                              Local resolution                                         33
# ...                                                                                  ...
# Violence and sexual offences Offender given a drugs possession warning                 1
#                              Offender given penalty notice                            24
#                              Status update unavailable                             57197
#                              Unable to prosecute suspect                             251
#                              Under investigation                                   62590
#
#                                                                             Longitude  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                               119
#                              Court result unavailable                              71
#                              Formal action is not in the public interest            1
#                              Investigation complete; no suspect identified      19136
#                              Local resolution                                      33
# ...                                                                               ...
# Violence and sexual offences Offender given a drugs possession warning              1
#                              Offender given penalty notice                         24
#                              Status update unavailable                          57197
#                              Unable to prosecute suspect                          251
#                              Under investigation                                62590
#
#                                                                             Latitude  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                              119
#                              Court result unavailable                             71
#                              Formal action is not in the public interest           1
#                              Investigation complete; no suspect identified     19136
#                              Local resolution                                     33
# ...                                                                              ...
# Violence and sexual offences Offender given a drugs possession warning             1
#                              Offender given penalty notice                        24
#                              Status update unavailable                         57197
#                              Unable to prosecute suspect                         251
#                              Under investigation                               62590
#
#                                                                             Location  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                              119
#                              Court result unavailable                             71
#                              Formal action is not in the public interest           1
#                              Investigation complete; no suspect identified     19136
#                              Local resolution                                     33
# ...                                                                              ...
# Violence and sexual offences Offender given a drugs possession warning             1
#                              Offender given penalty notice                        24
#                              Status update unavailable                         57197
#                              Unable to prosecute suspect                         251
#                              Under investigation                               62590
#
#                                                                             LSOA code  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                               119
#                              Court result unavailable                              71
#                              Formal action is not in the public interest            1
#                              Investigation complete; no suspect identified      19136
#                              Local resolution                                      33
# ...                                                                               ...
# Violence and sexual offences Offender given a drugs possession warning              1
#                              Offender given penalty notice                         24
#                              Status update unavailable                          57197
#                              Unable to prosecute suspect                          251
#                              Under investigation                                62590
#
#                                                                             LSOA name  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                               119
#                              Court result unavailable                              71
#                              Formal action is not in the public interest            1
#                              Investigation complete; no suspect identified      19136
#                              Local resolution                                      33
# ...                                                                               ...
# Violence and sexual offences Offender given a drugs possession warning              1
#                              Offender given penalty notice                         24
#                              Status update unavailable                          57197
#                              Unable to prosecute suspect                          251
#                              Under investigation                                62590
#
#                                                                             Context  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                               0
#                              Court result unavailable                             0
#                              Formal action is not in the public interest          0
#                              Investigation complete; no suspect identified        0
#                              Local resolution                                     0
# ...                                                                             ...
# Violence and sexual offences Offender given a drugs possession warning            0
#                              Offender given penalty notice                        0
#                              Status update unavailable                            0
#                              Unable to prosecute suspect                          0
#                              Under investigation                                  0
#
#                                                                             Location type  \
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                                   119
#                              Court result unavailable                                  71
#                              Formal action is not in the public interest                1
#                              Investigation complete; no suspect identified          19136
#                              Local resolution                                          33
# ...                                                                                   ...
# Violence and sexual offences Offender given a drugs possession warning                  1
#                              Offender given penalty notice                             24
#                              Status update unavailable                              57197
#                              Unable to prosecute suspect                              251
#                              Under investigation                                    62590
#
#                                                                             Season
# Crime type                   Last outcome category
# Bicycle theft                Awaiting court outcome                            104
#                              Court result unavailable                           71
#                              Formal action is not in the public interest         1
#                              Investigation complete; no suspect identified   18051
#                              Local resolution                                   30
# ...                                                                            ...
# Violence and sexual offences Offender given a drugs possession warning           1
#                              Offender given penalty notice                      22
#                              Status update unavailable                       57197
#                              Unable to prosecute suspect                       229
#                              Under investigation                             45958
#
# [142 rows x 12 columns]

# %%
# Create a line chart showing last outcome category by crime type.
df_pivot_outcome.plot()
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# Show for which crime type the outcome was "Formal action is not in the public interest"?
df_pivot_outcome['Formal action is not in the public interest']
# Out:
# Crime type
# Bicycle theft                    1.0
# Burglary                         1.0
# Criminal damage and arson        6.0
# Drugs                           49.0
# Other crime                      9.0
# Other theft                      5.0
# Possession of weapons            7.0
# Public order                    27.0
# Robbery                          2.0
# Shoplifting                     20.0
# Theft from the person            3.0
# Vehicle crime                    1.0
# Violence and sexual offences    20.0
# Name: Formal action is not in the public interest, dtype: float64

# %%
# Show the counts of crimes with outcome "Formal action is not in the public interest".
df_pivot_outcome['Formal action is not in the public interest'].plot(kind="bar")
plt.xticks(rotation=90)
plt.show()

# %%
# Create a pivot table which shows how location type and last outcome category are connected
df_pivot1 = pd.pivot_table(df, values='Reported by', index='Location type', columns='Last outcome category', aggfunc='count')
df_pivot1
# Out:
# Last outcome category                           Action to be taken by another organisation  \
# Location type
# On Street                                                                             19.0
# On or near Airport/Airfield                                                            NaN
# On or near Bus/Coach Station                                                           NaN
# On or near Conference/Exhibition Centre                                                1.0
# On or near Further/Higher Educational Building                                         NaN
# On or near Hospital                                                                    NaN
# On or near Meridian Square                                                             NaN
# On or near Nightclub                                                                   NaN
# On or near Park/Open Space                                                             NaN
# On or near Parking Area                                                                NaN
# On or near Petrol Station                                                              NaN
# On or near Police Station                                                              NaN
# On or near Shopping Area                                                               NaN
# On or near Sports/Recreation Area                                                      NaN
# On or near Supermarket                                                                 NaN
# On or near Theatre/Concert Hall                                                        NaN
# On or near Underpass                                                                   NaN
#
# Last outcome category                           Awaiting court outcome  \
# Location type
# On Street                                                      14518.0
# On or near Airport/Airfield                                       38.0
# On or near Bus/Coach Station                                      57.0
# On or near Conference/Exhibition Centre                           46.0
# On or near Further/Higher Educational Building                   108.0
# On or near Hospital                                              149.0
# On or near Meridian Square                                        57.0
# On or near Nightclub                                             247.0
# On or near Park/Open Space                                        36.0
# On or near Parking Area                                          516.0
# On or near Petrol Station                                        364.0
# On or near Police Station                                        481.0
# On or near Shopping Area                                         557.0
# On or near Sports/Recreation Area                                202.0
# On or near Supermarket                                           769.0
# On or near Theatre/Concert Hall                                  133.0
# On or near Underpass                                             157.0
#
# Last outcome category                           Court result unavailable  \
# Location type
# On Street                                                        12633.0
# On or near Airport/Airfield                                         43.0
# On or near Bus/Coach Station                                        37.0
# On or near Conference/Exhibition Centre                             40.0
# On or near Further/Higher Educational Building                     100.0
# On or near Hospital                                                 97.0
# On or near Meridian Square                                          23.0
# On or near Nightclub                                               108.0
# On or near Park/Open Space                                          31.0
# On or near Parking Area                                            469.0
# On or near Petrol Station                                          350.0
# On or near Police Station                                          364.0
# On or near Shopping Area                                           399.0
# On or near Sports/Recreation Area                                  171.0
# On or near Supermarket                                             772.0
# On or near Theatre/Concert Hall                                     87.0
# On or near Underpass                                               135.0
#
# Last outcome category                           Formal action is not in the public interest  \
# Location type
# On Street                                                                             109.0
# On or near Airport/Airfield                                                             NaN
# On or near Bus/Coach Station                                                            3.0
# On or near Conference/Exhibition Centre                                                 NaN
# On or near Further/Higher Educational Building                                          NaN
# On or near Hospital                                                                     2.0
# On or near Meridian Square                                                              NaN
# On or near Nightclub                                                                    3.0
# On or near Park/Open Space                                                              1.0
# On or near Parking Area                                                                 5.0
# On or near Petrol Station                                                               NaN
# On or near Police Station                                                               6.0
# On or near Shopping Area                                                                1.0
# On or near Sports/Recreation Area                                                       NaN
# On or near Supermarket                                                                 18.0
# On or near Theatre/Concert Hall                                                         1.0
# On or near Underpass                                                                    2.0
#
# Last outcome category                           Further investigation is not in the public interest  \
# Location type
# On Street                                                                                     6.0
# On or near Airport/Airfield                                                                   NaN
# On or near Bus/Coach Station                                                                  NaN
# On or near Conference/Exhibition Centre                                                       1.0
# On or near Further/Higher Educational Building                                                NaN
# On or near Hospital                                                                           NaN
# On or near Meridian Square                                                                    NaN
# On or near Nightclub                                                                          NaN
# On or near Park/Open Space                                                                    NaN
# On or near Parking Area                                                                       NaN
# On or near Petrol Station                                                                     NaN
# On or near Police Station                                                                     NaN
# On or near Shopping Area                                                                      NaN
# On or near Sports/Recreation Area                                                             NaN
# On or near Supermarket                                                                        2.0
# On or near Theatre/Concert Hall                                                               NaN
# On or near Underpass                                                                          NaN
#
# Last outcome category                           Investigation complete; no suspect identified  \
# Location type
# On Street                                                                            388786.0
# On or near Airport/Airfield                                                             394.0
# On or near Bus/Coach Station                                                            849.0
# On or near Conference/Exhibition Centre                                                1331.0
# On or near Further/Higher Educational Building                                         2900.0
# On or near Hospital                                                                    3225.0
# On or near Meridian Square                                                              942.0
# On or near Nightclub                                                                   4965.0
# On or near Park/Open Space                                                              957.0
# On or near Parking Area                                                               12275.0
# On or near Petrol Station                                                              9252.0
# On or near Police Station                                                              1976.0
# On or near Shopping Area                                                              12815.0
# On or near Sports/Recreation Area                                                      5951.0
# On or near Supermarket                                                                19411.0
# On or near Theatre/Concert Hall                                                        2664.0
# On or near Underpass                                                                   4217.0
#
# Last outcome category                           Local resolution  \
# Location type
# On Street                                                21732.0
# On or near Airport/Airfield                                134.0
# On or near Bus/Coach Station                                85.0
# On or near Conference/Exhibition Centre                     52.0
# On or near Further/Higher Educational Building             208.0
# On or near Hospital                                         83.0
# On or near Meridian Square                                 133.0
# On or near Nightclub                                       367.0
# On or near Park/Open Space                                 131.0
# On or near Parking Area                                    981.0
# On or near Petrol Station                                  435.0
# On or near Police Station                                  218.0
# On or near Shopping Area                                   733.0
# On or near Sports/Recreation Area                          502.0
# On or near Supermarket                                    1016.0
# On or near Theatre/Concert Hall                            177.0
# On or near Underpass                                       289.0
#
# Last outcome category                           Offender given a caution  \
# Location type
# On Street                                                         4822.0
# On or near Airport/Airfield                                         20.0
# On or near Bus/Coach Station                                        11.0
# On or near Conference/Exhibition Centre                             16.0
# On or near Further/Higher Educational Building                      25.0
# On or near Hospital                                                 23.0
# On or near Meridian Square                                          10.0
# On or near Nightclub                                                61.0
# On or near Park/Open Space                                           9.0
# On or near Parking Area                                            132.0
# On or near Petrol Station                                           66.0
# On or near Police Station                                           83.0
# On or near Shopping Area                                           106.0
# On or near Sports/Recreation Area                                   78.0
# On or near Supermarket                                             174.0
# On or near Theatre/Concert Hall                                     30.0
# On or near Underpass                                                56.0
#
# Last outcome category                           Offender given a drugs possession warning  \
# Location type
# On Street                                                                           324.0
# On or near Airport/Airfield                                                           NaN
# On or near Bus/Coach Station                                                          7.0
# On or near Conference/Exhibition Centre                                               2.0
# On or near Further/Higher Educational Building                                        2.0
# On or near Hospital                                                                   NaN
# On or near Meridian Square                                                            NaN
# On or near Nightclub                                                                  2.0
# On or near Park/Open Space                                                            4.0
# On or near Parking Area                                                              13.0
# On or near Petrol Station                                                             4.0
# On or near Police Station                                                             3.0
# On or near Shopping Area                                                             12.0
# On or near Sports/Recreation Area                                                     2.0
# On or near Supermarket                                                                8.0
# On or near Theatre/Concert Hall                                                       NaN
# On or near Underpass                                                                 21.0
#
# Last outcome category                           Offender given penalty notice  \
# Location type
# On Street                                                              5335.0
# On or near Airport/Airfield                                               1.0
# On or near Bus/Coach Station                                             18.0
# On or near Conference/Exhibition Centre                                  16.0
# On or near Further/Higher Educational Building                           45.0
# On or near Hospital                                                      21.0
# On or near Meridian Square                                               26.0
# On or near Nightclub                                                     72.0
# On or near Park/Open Space                                               23.0
# On or near Parking Area                                                 232.0
# On or near Petrol Station                                                96.0
# On or near Police Station                                                74.0
# On or near Shopping Area                                                144.0
# On or near Sports/Recreation Area                                       118.0
# On or near Supermarket                                                  252.0
# On or near Theatre/Concert Hall                                          28.0
# On or near Underpass                                                     70.0
#
# Last outcome category                           Status update unavailable  \
# Location type
# On Street                                                         95212.0
# On or near Airport/Airfield                                          32.0
# On or near Bus/Coach Station                                        251.0
# On or near Conference/Exhibition Centre                             245.0
# On or near Further/Higher Educational Building                      705.0
# On or near Hospital                                                 940.0
# On or near Meridian Square                                          199.0
# On or near Nightclub                                                889.0
# On or near Park/Open Space                                          196.0
# On or near Parking Area                                            2822.0
# On or near Petrol Station                                          1995.0
# On or near Police Station                                           768.0
# On or near Shopping Area                                           2627.0
# On or near Sports/Recreation Area                                  1693.0
# On or near Supermarket                                             4595.0
# On or near Theatre/Concert Hall                                     504.0
# On or near Underpass                                                999.0
#
# Last outcome category                           Suspect charged as part of another case  \
# Location type
# On Street                                                                          29.0
# On or near Airport/Airfield                                                         NaN
# On or near Bus/Coach Station                                                        NaN
# On or near Conference/Exhibition Centre                                             NaN
# On or near Further/Higher Educational Building                                      NaN
# On or near Hospital                                                                 NaN
# On or near Meridian Square                                                          NaN
# On or near Nightclub                                                                NaN
# On or near Park/Open Space                                                          1.0
# On or near Parking Area                                                             NaN
# On or near Petrol Station                                                           NaN
# On or near Police Station                                                           NaN
# On or near Shopping Area                                                            NaN
# On or near Sports/Recreation Area                                                   NaN
# On or near Supermarket                                                              1.0
# On or near Theatre/Concert Hall                                                     NaN
# On or near Underpass                                                                1.0
#
# Last outcome category                           Unable to prosecute suspect  \
# Location type
# On Street                                                             431.0
# On or near Airport/Airfield                                             NaN
# On or near Bus/Coach Station                                            8.0
# On or near Conference/Exhibition Centre                                 5.0
# On or near Further/Higher Educational Building                          2.0
# On or near Hospital                                                     1.0
# On or near Meridian Square                                              NaN
# On or near Nightclub                                                    3.0
# On or near Park/Open Space                                              7.0
# On or near Parking Area                                                 7.0
# On or near Petrol Station                                               NaN
# On or near Police Station                                              25.0
# On or near Shopping Area                                                8.0
# On or near Sports/Recreation Area                                       NaN
# On or near Supermarket                                                 27.0
# On or near Theatre/Concert Hall                                         2.0
# On or near Underpass                                                    6.0
#
# Last outcome category                           Under investigation
# Location type
# On Street                                                  123300.0
# On or near Airport/Airfield                                    40.0
# On or near Bus/Coach Station                                  339.0
# On or near Conference/Exhibition Centre                       402.0
# On or near Further/Higher Educational Building               1089.0
# On or near Hospital                                          1219.0
# On or near Meridian Square                                    482.0
# On or near Nightclub                                         2215.0
# On or near Park/Open Space                                    316.0
# On or near Parking Area                                      4437.0
# On or near Petrol Station                                    2839.0
# On or near Police Station                                     969.0
# On or near Shopping Area                                     4362.0
# On or near Sports/Recreation Area                            2115.0
# On or near Supermarket                                       6188.0
# On or near Theatre/Concert Hall                              1082.0
# On or near Underpass                                         1465.0

# %%
# Create a stacked bar chart of the above last outcome category sorted by location type.
ax = df_pivot1.plot.bar(stacked=True, figsize=(15,20))
ax.set_ylim(0,700000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# Which location type has 'Investigation complete, no suspect identified' as outcome?
df_pivot1['Investigation complete; no suspect identified']
# Out:
# Location type
# On Street                                         388786.0
# On or near Airport/Airfield                          394.0
# On or near Bus/Coach Station                         849.0
# On or near Conference/Exhibition Centre             1331.0
# On or near Further/Higher Educational Building      2900.0
# On or near Hospital                                 3225.0
# On or near Meridian Square                           942.0
# On or near Nightclub                                4965.0
# On or near Park/Open Space                           957.0
# On or near Parking Area                            12275.0
# On or near Petrol Station                           9252.0
# On or near Police Station                           1976.0
# On or near Shopping Area                           12815.0
# On or near Sports/Recreation Area                   5951.0
# On or near Supermarket                             19411.0
# On or near Theatre/Concert Hall                     2664.0
# On or near Underpass                                4217.0
# Name: Investigation complete; no suspect identified, dtype: float64

# %%
figure(figsize=(12, 8), dpi=80)
df_pivot1['Investigation complete; no suspect identified'].plot(kind="bar")
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# Which crime type has 'Investigation complete, no suspect identified' as outcome?
df_pivot_outcome['Investigation complete; no suspect identified']
# Out:
# Crime type
# Bicycle theft                    19136.0
# Burglary                         37154.0
# Criminal damage and arson        36333.0
# Drugs                             2356.0
# Other crime                       5084.0
# Other theft                      66585.0
# Possession of weapons             1050.0
# Public order                     29701.0
# Robbery                          11134.0
# Shoplifting                      21233.0
# Theft from the person            28473.0
# Vehicle crime                    91666.0
# Violence and sexual offences    123005.0
# Name: Investigation complete; no suspect identified, dtype: float64

# %%
df_pivot_outcome['Investigation complete; no suspect identified'].plot(kind="bar")
plt.xticks(rotation=90)
plt.show()

# %%
# Which crime type has what outcome (with which prevalence)?
from matplotlib.pyplot import figure
figure(figsize=(100, 100), dpi=100)
g = sns.FacetGrid(df, row = "Last outcome category")
g = g.map(plt.hist, "Crime type")
plt.xticks(rotation=90)
plt.show()

# %%
# Show the total counts for the different last outcome categories
df['Last outcome category'].value_counts()
# Out:
# Investigation complete; no suspect identified          472910
# Under investigation                                    152859
# Status update unavailable                              114672
# Local resolution                                        27276
# Awaiting court outcome                                  18435
# Court result unavailable                                15859
# Offender given penalty notice                            6571
# Offender given a caution                                 5722
# Unable to prosecute suspect                               532
# Offender given a drugs possession warning                 404
# Formal action is not in the public interest               151
# Suspect charged as part of another case                    32
# Action to be taken by another organisation                 20
# Further investigation is not in the public interest         9
# Name: Last outcome category, dtype: int64

# %%
# Show the percentage distribution per last outcome category
df['Last outcome category'].value_counts(normalize = True)
# Out:
# Investigation complete; no suspect identified          0.579936
# Under investigation                                    0.187453
# Status update unavailable                              0.140624
# Local resolution                                       0.033449
# Awaiting court outcome                                 0.022607
# Court result unavailable                               0.019448
# Offender given penalty notice                          0.008058
# Offender given a caution                               0.007017
# Unable to prosecute suspect                            0.000652
# Offender given a drugs possession warning              0.000495
# Formal action is not in the public interest            0.000185
# Suspect charged as part of another case                0.000039
# Action to be taken by another organisation             0.000025
# Further investigation is not in the public interest    0.000011
# Name: Last outcome category, dtype: float64

# %%
# Create labels for a pie chart on outcomes
outcome = ['Investigation complete; no suspect identified (58.0%)', 'Under investigation (18.7%)', 'Status update unavailable (14.1%)', 'Local resolution (3.3%)', 'Awaiting court outcome (2.3%)', 'Court result unavailable (1.9%)','Offender given penalty notice (0.8%)','Offender given a caution (0.7%)', 'Unable to prosecute suspect (0.07%)','Offender given a drugs possession warning (0.05%)', 'Formal action is not in the public interest (0.02%)', 'Suspect charged as part of another case (0.004%)', 'Action to be taken by another organisation (0.003%)', 'Further investigation is not in the public interest (0.001%)']

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True

labels = outcome
sizes =  df['Last outcome category'].value_counts()

patches, texts = plt.pie(sizes, shadow=True, startangle=90)
plt.legend(patches,labels,bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.axis('equal')

plt.show()

# %%
# Create a new table with the top 9 outcomes and their total counts 
Last_outcome_category = df['Last outcome category'].value_counts().rename_axis('outcome').reset_index(name='counts')
Last_outcome_category.iloc[0:9]
# Out:
#                                          outcome  counts
# 0  Investigation complete; no suspect identified  472910
# 1                            Under investigation  152859
# 2                      Status update unavailable  114672
# 3                               Local resolution   27276
# 4                         Awaiting court outcome   18435
# 5                       Court result unavailable   15859
# 6                  Offender given penalty notice    6571
# 7                       Offender given a caution    5722
# 8                    Unable to prosecute suspect     532

# %%
# Create a bar chart of the top 9 outcomes and their counts
top_nine = Last_outcome_category.iloc[0:9]
plt.figure(figsize=(10,7.5))
ax = sns.barplot(x='outcome', y='counts', hue='outcome', data=top_nine, dodge=False)
ax.set(xticklabels=[])

plt.show()

# %%
# Percentage of missing data by column
for col in df.columns:
    pct_missing =100* np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# Crime ID - 31.1250961813776%
# Month - 0.0%
# Reported by - 0.0%
# Falls within - 0.0%
# Longitude - 0.0%
# Latitude - 0.0%
# Location - 0.0%
# LSOA code - 0.0%
# LSOA name - 0.0%
# Crime type - 0.0%
# Last outcome category - 31.1250961813776%
# Context - 100.0%
# Location type - 0.0%
# Season - 7.646197805502039%

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('/Users/theres/Downloads/Data-Science-Group-4/data/preprocessed/data_location_type_season_added.csv')
# Out:
# /Users/theres/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                                                   Crime ID       Month  \
# 0                                                      NaN  2021-06-01
# 1                                                      NaN  2021-06-01
# 2                                                      NaN  2021-06-01
# 3        69739dcc3580a6a58699ba4aeaa4b43c01d5a20c4b4a95...  2021-06-01
# 4        e9243631051c322e261ac7278695cd3ec957d9d055cd47...  2021-06-01
# ...                                                    ...         ...
# 1182889                                                NaN  2021-08-01
# 1182890                                                NaN  2021-08-01
# 1182891                                                NaN  2021-08-01
# 1182892                                                NaN  2021-08-01
# 1182893                                                NaN  2021-08-01
#
#                          Reported by                 Falls within  Longitude  \
# ...

# %%
season_pivot = pd.pivot_table(df, values='Reported by', index='Season',
                          aggfunc='count')

season_pivot
# Out:
#         Reported by
# Season
# Fall         283319
# Spring       272786
# Summer       281504
# Winter       255265

# %%
season_pivot = season_pivot.reindex(index=['Spring','Summer','Fall','Winter'])

# %%
season_pivot
# Out:
#         Reported by
# Season
# Spring       272786
# Summer       281504
# Fall         283319
# Winter       255265

# %%
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20,15)

# %%
season_pivot = season_pivot.reset_index()

# %%
plt.figure(figsize=(10,10))
plt.bar(season_pivot['Season'], season_pivot['Reported by'], Width =0.8)
plt.ylabel("# of Crimes")
plt.xlabel("Season")
plt.title("Bar plot of total crimes by season")

plt.show()
# Out:
# <ipython-input-11-af8a7fc0d23c>:2: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.bar(season_pivot['Season'], season_pivot['Reported by'], Width =0.8)

# %%
loc_grp=df.groupby(['Location type'])

# %%
loc_grp.get_group('On Street')
# Out:
#                                                   Crime ID       Month  \
# 0                                                      NaN  2021-06-01
# 2                                                      NaN  2021-06-01
# 3        69739dcc3580a6a58699ba4aeaa4b43c01d5a20c4b4a95...  2021-06-01
# 4        e9243631051c322e261ac7278695cd3ec957d9d055cd47...  2021-06-01
# 5        d4b3cf72983c35b9ce7f4c8ad797acd665e8c0a5b8fe30...  2021-06-01
# ...                                                    ...         ...
# 1164330  c890defb5d13f48fdb1cd4d79e1fd84e90afb2e8136fc2...  2021-03-01
# 1164331  42d2c512be19f8e6aa12d199d9ae07f51f61494679a68f...  2021-03-01
# 1164332  42c40b0a52724d99c20c504ed1eee3dfcda8bfdd4b97f0...  2021-03-01
# 1164333  62d6af7093b12794a23832667a3e4a1732fcf4eb1cc3a2...  2021-03-01
# 1164334  3e478cd8bdf920fda6cd4fac46fc5584bc756dedeeb648...  2021-03-01
#
#                          Reported by                 Falls within  Longitude  \
# ...

# %%
df['Crime type'].value_counts(normalize=True)
# Out:
# Anti-social behaviour           0.294940
# Violence and sexual offences    0.221158
# Vehicle crime                   0.090364
# Other theft                     0.078779
# Public order                    0.055392
# Burglary                        0.048876
# Criminal damage and arson       0.048709
# Drugs                           0.040853
# Theft from the person           0.034463
# Shoplifting                     0.030895
# Robbery                         0.021124
# Bicycle theft                   0.020315
# Other crime                     0.009463
# Possession of weapons           0.004669
# Name: Crime type, dtype: float64

# %%
crime_grp = df.groupby(['Crime type'])

# %%
crime_grp.get_group('Anti-social behaviour')
# Out:
#         Crime ID       Month                  Reported by  \
# 0            NaN  2021-06-01  Metropolitan Police Service
# 1            NaN  2021-06-01  Metropolitan Police Service
# 2            NaN  2021-06-01  Metropolitan Police Service
# 35           NaN  2021-06-01  Metropolitan Police Service
# 42           NaN  2021-06-01  Metropolitan Police Service
# ...          ...         ...                          ...
# 1164282      NaN  2021-03-01        City of London Police
# 1164283      NaN  2021-03-01        City of London Police
# 1164284      NaN  2021-03-01        City of London Police
# 1164285      NaN  2021-03-01        City of London Police
# 1164286      NaN  2021-03-01        City of London Police
#
#                         Falls within  Longitude   Latitude  \
# 0        Metropolitan Police Service   0.140035  51.589112
# 1        Metropolitan Police Service   0.137065  51.583672
# 2        Metropolitan Police Service   0.134947  51.588063
# ...

# %%
crime_grp['Location type'].value_counts(normalize=True).head(60)
# Out:
# Crime type                 Location type
# Anti-social behaviour      On Street                                         0.888848
#                            On or near Parking Area                           0.020680
#                            On or near Supermarket                            0.020250
#                            On or near Sports/Recreation Area                 0.014423
#                            On or near Petrol Station                         0.010218
#                            On or near Shopping Area                          0.009608
#                            On or near Underpass                              0.007676
#                            On or near Further/Higher Educational Building    0.004919
#                            On or near Theatre/Concert Hall                   0.004663
#                            On or near Nightclub                              0.004563
# ...

# %%
crime_grp['Location type'].value_counts(normalize=True).loc['Violence and sexual offences']
# Out:
# Location type
# On Street                                         0.851961
# On or near Supermarket                            0.025672
# On or near Parking Area                           0.020546
# On or near Sports/Recreation Area                 0.014174
# On or near Petrol Station                         0.012068
# On or near Shopping Area                          0.011976
# On or near Hospital                               0.010042
# On or near Train Station/Tram Stop                0.009962
# On or near Nightclub                              0.007913
# On or near Underpass                              0.007416
# On or near London Underground Station             0.007297
# On or near Police Station                         0.005600
# On or near Further/Higher Educational Building    0.005405
# On or near Theatre/Concert Hall                   0.003746
# On or near Conference/Exhibition Centre           0.001892
# On or near Park/Open Space                        0.001743
# ...

# %%
df['Last outcome category'].value_counts()
# Out:
# Investigation complete; no suspect identified          459369
# Under investigation                                    198135
# Status update unavailable                               85393
# Local resolution                                        26776
# Awaiting court outcome                                  19377
# Court result unavailable                                13325
# Offender given penalty notice                            6493
# Offender given a caution                                 5524
# Unable to prosecute suspect                               490
# Offender given a drugs possession warning                 397
# Formal action is not in the public interest               119
# Suspect charged as part of another case                    26
# Action to be taken by another organisation                 19
# Further investigation is not in the public interest         9
# Name: Last outcome category, dtype: int64

# %%
df['Location type'].value_counts(normalize=True)
# Out:
# On Street                                         0.826245
# On or near Supermarket                            0.034067
# On or near Parking Area                           0.024604
# On or near Shopping Area                          0.021233
# On or near Petrol Station                         0.016034
# On or near Sports/Recreation Area                 0.013411
# On or near Train Station/Tram Stop                0.009449
# On or near Nightclub                              0.008897
# On or near Underpass                              0.008535
# On or near London Underground Station             0.006241
# On or near Further/Higher Educational Building    0.005833
# On or near Hospital                               0.005612
# On or near Police Station                         0.005485
# On or near Theatre/Concert Hall                   0.005356
# On or near Conference/Exhibition Centre           0.002473
# On or near Park/Open Space                        0.002092
# ...

# %%
df['Last outcome category'].count()
# Out:
# 815452

# %%
df['Last outcome category'].value_counts(normalize=True)
# Out:
# Investigation complete; no suspect identified          0.563331
# Under investigation                                    0.242976
# Status update unavailable                              0.104719
# Local resolution                                       0.032836
# Awaiting court outcome                                 0.023762
# Court result unavailable                               0.016341
# Offender given penalty notice                          0.007962
# Offender given a caution                               0.006774
# Unable to prosecute suspect                            0.000601
# Offender given a drugs possession warning              0.000487
# Formal action is not in the public interest            0.000146
# Suspect charged as part of another case                0.000032
# Action to be taken by another organisation             0.000023
# Further investigation is not in the public interest    0.000011
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).head(60)
# Out:
# Crime type                 Last outcome category
# Bicycle theft              Investigation complete; no suspect identified          0.815807
#                            Under investigation                                    0.154334
#                            Status update unavailable                              0.019487
#                            Awaiting court outcome                                 0.004991
#                            Court result unavailable                               0.002604
#                            Local resolution                                       0.001345
#                            Offender given a caution                               0.000998
#                            Unable to prosecute suspect                            0.000391
#                            Formal action is not in the public interest            0.000043
# Burglary                   Investigation complete; no suspect identified          0.613231
# ...

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Other theft']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.709395
# Under investigation                              0.223569
# Status update unavailable                        0.058934
# Awaiting court outcome                           0.002993
# Local resolution                                 0.001984
# Court result unavailable                         0.001918
# Offender given a caution                         0.000921
# Unable to prosecute suspect                      0.000164
# Offender given penalty notice                    0.000055
# Formal action is not in the public interest      0.000044
# Action to be taken by another organisation       0.000022
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Violence and sexual offences']
# Out:
# Last outcome category
# Investigation complete; no suspect identified          0.462710
# Under investigation                                    0.312063
# Status update unavailable                              0.172514
# Awaiting court outcome                                 0.022241
# Court result unavailable                               0.013295
# Offender given a caution                               0.008639
# Local resolution                                       0.007425
# Unable to prosecute suspect                            0.000899
# Offender given penalty notice                          0.000105
# Formal action is not in the public interest            0.000054
# Action to be taken by another organisation             0.000039
# Further investigation is not in the public interest    0.000012
# Offender given a drugs possession warning              0.000004
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Vehicle crime']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.844909
# Under investigation                              0.122985
# Status update unavailable                        0.023364
# Awaiting court outcome                           0.004680
# Court result unavailable                         0.003527
# Local resolution                                 0.000281
# Offender given a caution                         0.000206
# Unable to prosecute suspect                      0.000028
# Formal action is not in the public interest      0.000009
# Offender given penalty notice                    0.000009
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Criminal damage and arson']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.634850
# Under investigation                              0.210160
# Status update unavailable                        0.088550
# Awaiting court outcome                           0.022396
# Court result unavailable                         0.017279
# Local resolution                                 0.014140
# Offender given a caution                         0.010556
# Offender given penalty notice                    0.001480
# Unable to prosecute suspect                      0.000499
# Formal action is not in the public interest      0.000071
# Suspect charged as part of another case          0.000018
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Burglary']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.613231
# Under investigation                              0.285588
# Status update unavailable                        0.066467
# Awaiting court outcome                           0.020586
# Court result unavailable                         0.012085
# Offender given a caution                         0.000796
# Local resolution                                 0.000519
# Suspect charged as part of another case          0.000433
# Unable to prosecute suspect                      0.000242
# Offender given penalty notice                    0.000035
# Formal action is not in the public interest      0.000017
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Public order']
# Out:
# Last outcome category
# Investigation complete; no suspect identified          0.467961
# Under investigation                                    0.298811
# Status update unavailable                              0.163481
# Awaiting court outcome                                 0.031326
# Court result unavailable                               0.020004
# Local resolution                                       0.007435
# Offender given penalty notice                          0.004875
# Offender given a caution                               0.004422
# Unable to prosecute suspect                            0.001280
# Formal action is not in the public interest            0.000356
# Action to be taken by another organisation             0.000032
# Further investigation is not in the public interest    0.000016
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Theft from the person']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.715298
# Under investigation                              0.229822
# Status update unavailable                        0.045363
# Awaiting court outcome                           0.005203
# Court result unavailable                         0.002301
# Local resolution                                 0.001203
# Offender given a caution                         0.000549
# Offender given penalty notice                    0.000105
# Unable to prosecute suspect                      0.000105
# Formal action is not in the public interest      0.000052
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Shoplifting']
# Out:
# Last outcome category
# Investigation complete; no suspect identified          0.571871
# Under investigation                                    0.238566
# Status update unavailable                              0.081099
# Awaiting court outcome                                 0.036717
# Local resolution                                       0.033480
# Court result unavailable                               0.025843
# Offender given penalty notice                          0.006115
# Offender given a caution                               0.003874
# Unable to prosecute suspect                            0.001965
# Formal action is not in the public interest            0.000415
# Further investigation is not in the public interest    0.000055
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Bicycle theft']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.815807
# Under investigation                              0.154334
# Status update unavailable                        0.019487
# Awaiting court outcome                           0.004991
# Court result unavailable                         0.002604
# Local resolution                                 0.001345
# Offender given a caution                         0.000998
# Unable to prosecute suspect                      0.000391
# Formal action is not in the public interest      0.000043
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Robbery']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.439041
# Under investigation                              0.362216
# Status update unavailable                        0.149375
# Awaiting court outcome                           0.031404
# Court result unavailable                         0.015908
# Offender given a caution                         0.000987
# Local resolution                                 0.000658
# Unable to prosecute suspect                      0.000370
# Offender given penalty notice                    0.000041
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Other crime']
# Out:
# Last outcome category
# Investigation complete; no suspect identified    0.445100
# Under investigation                              0.242831
# Status update unavailable                        0.175953
# Awaiting court outcome                           0.050726
# Court result unavailable                         0.040290
# Local resolution                                 0.031307
# Offender given a caution                         0.011887
# Formal action is not in the public interest      0.000726
# Unable to prosecute suspect                      0.000635
# Action to be taken by another organisation       0.000454
# Offender given penalty notice                    0.000091
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Drugs']
# Out:
# Last outcome category
# Local resolution                                       0.461763
# Offender given penalty notice                          0.124558
# Awaiting court outcome                                 0.093312
# Under investigation                                    0.087813
# Court result unavailable                               0.076410
# Status update unavailable                              0.061703
# Investigation complete; no suspect identified          0.048745
# Offender given a caution                               0.035935
# Offender given a drugs possession warning              0.008440
# Formal action is not in the public interest            0.000895
# Unable to prosecute suspect                            0.000362
# Further investigation is not in the public interest    0.000064
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts(normalize=True).loc['Possession of weapons']
# Out:
# Last outcome category
# Awaiting court outcome                           0.221968
# Under investigation                              0.208452
# Investigation complete; no suspect identified    0.192271
# Court result unavailable                         0.181991
# Status update unavailable                        0.131925
# Offender given a caution                         0.049686
# Local resolution                                 0.011612
# Formal action is not in the public interest      0.000952
# Offender given penalty notice                    0.000571
# Unable to prosecute suspect                      0.000571
# Name: Last outcome category, dtype: float64

# %%
crime_grp['Last outcome category'].value_counts().loc['Anti-social behaviour']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-c803fbd9744a> in <module>
# ----> 1 crime_grp['Last outcome category'].value_counts().loc['Anti-social behaviour']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %%
outcome_grp = df.groupby(['Last outcome category'])

# %%
outcome_grp['Crime type'].value_counts(normalize=True).loc['Investigation complete; no suspect identified']
# Out:
# Crime type
# Violence and sexual offences    0.258962
# Vehicle crime                   0.196095
# Other theft                     0.140869
# Criminal damage and arson       0.077504
# Burglary                        0.077104
# Public order                    0.062893
# Theft from the person           0.059556
# Shoplifting                     0.044992
# Bicycle theft                   0.040919
# Robbery                         0.023251
# Other crime                     0.010678
# Drugs                           0.004979
# Possession of weapons           0.002199
# Name: Crime type, dtype: float64

# %%
outcome_grp['Crime type'].value_counts().loc['Formal action is not in the public interest']
# Out:
# Crime type
# Drugs                           42
# Public order                    22
# Shoplifting                     15
# Violence and sexual offences    14
# Other crime                      8
# Possession of weapons            5
# Criminal damage and arson        4
# Other theft                      4
# Theft from the person            2
# Bicycle theft                    1
# Burglary                         1
# Vehicle crime                    1
# Name: Crime type, dtype: int64

# %%
outcome_grp['Location type'].value_counts(normalize=True).loc['Investigation complete; no suspect identified']
# Out:
# Location type
# On Street                                         0.822454
# On or near Supermarket                            0.041085
# On or near Shopping Area                          0.026965
# On or near Parking Area                           0.025988
# On or near Petrol Station                         0.019721
# On or near Sports/Recreation Area                 0.012565
# On or near Nightclub                              0.010221
# On or near Underpass                              0.008890
# On or near Hospital                               0.006866
# On or near Further/Higher Educational Building    0.006071
# On or near Theatre/Concert Hall                   0.005497
# On or near Police Station                         0.004188
# On or near Conference/Exhibition Centre           0.002817
# On or near Park/Open Space                        0.002029
# On or near Meridian Square                        0.002009
# On or near Bus/Coach Station                      0.001807
# ...

# %%
loc_grp['Crime type'].value_counts(normalize=True).loc['On or near Parking Area']
# Out:
# Crime type
# Anti-social behaviour           0.247904
# Violence and sexual offences    0.184683
# Other theft                     0.100673
# Vehicle crime                   0.080607
# Shoplifting                     0.080264
# Public order                    0.057930
# Theft from the person           0.053807
# Drugs                           0.052364
# Criminal damage and arson       0.041163
# Burglary                        0.036524
# Robbery                         0.026319
# Bicycle theft                   0.025495
# Other crime                     0.007628
# Possession of weapons           0.004639
# Name: Crime type, dtype: float64

# %%
import numpy as np

# %%
table_crime = df.groupby(by=['Season','Crime type']).count()

# %%
table_crime
# Out:
#                                      Crime ID  Month  Reported by  \
# Season Crime type
# Fall   Anti-social behaviour                0  77004        77004
#        Bicycle theft                     6147   6444         6444
#        Burglary                         14180  14196        14196
#        Criminal damage and arson        13220  13536        13536
#        Drugs                            10980  11253        11253
#        Other crime                       2763   2802         2802
#        Other theft                      23715  24258        24258
#        Possession of weapons             1334   1408         1408
#        Public order                     14551  15499        15499
#        Robbery                           6671   6838         6838
#        Shoplifting                       8632   8737         8737
#        Theft from the person            10425  11147        11147
#        Vehicle crime                    27156  27248        27248
# ...

# %%
table_location = df.groupby(by=['Season','Location type']).count()

# %%
table_location
# Out:
#                                                        Crime ID   Month  \
# Season Location type
# Fall   On Street                                         163813  232090
#        On or near Airport/Airfield                          206     257
#        On or near Bus/Coach Station                         440     580
#        On or near Conference/Exhibition Centre              545     724
#        On or near Further/Higher Educational Building      1383    1806
# ...                                                         ...     ...
# Winter On or near Sports/Recreation Area                   2051    3464
#        On or near Supermarket                              6788    8612
#        On or near Theatre/Concert Hall                      606     999
#        On or near Train Station/Tram Stop                     0    2063
#        On or near Underpass                                1306    2013
#
#                                                        Reported by  \
# ...

# %%
table_location.loc['Summer'].sort_values(by=['Reported by'],ascending=False).head(50)
# Out:
#                                                 Crime ID   Month  Reported by  \
# Location type
# On Street                                         161497  230072       230072
# On or near Supermarket                              7948    9567         9567
# On or near Parking Area                             5469    7059         7059
# On or near Shopping Area                            6135    6934         6934
# On or near Petrol Station                           3704    4478         4478
# On or near Sports/Recreation Area                   2652    3791         3791
# On or near Nightclub                                2737    3128         3128
# On or near Train Station/Tram Stop                     0    2897         2897
# On or near Underpass                                1920    2509         2509
# On or near London Underground Station                  0    1937         1937
# On or near Theatre/Concert Hall                     1337    1764         1764
# ...

# %%
df_pivot_crime = pd.pivot_table(df, values='Reported by', index='Season', columns='Crime type',
                          aggfunc='count')

# %%
df_pivot_crime
# Out:
# Crime type  Anti-social behaviour  Bicycle theft  Burglary  \
# Season
# Fall                        77004           6444     14196
# Spring                      84052           5689     12938
# Summer                      77427           6622     12776
# Winter                      92339           3555     13083
#
# Crime type  Criminal damage and arson  Drugs  Other crime  Other theft  \
# Season
# Fall                            13536  11253         2802        24258
# Spring                          13523  11763         2752        18376
# Summer                          14372   9842         2491        24916
# Winter                          11623  11794         2284        15985
#
# Crime type  Possession of weapons  Public order  Robbery  Shoplifting  \
# Season
# Fall                         1408         15499     6838         8737
# Spring                       1181         16052     5191         8306
# Summer                       1268         17500     5731         9338
# ...

# %%
df_pivot_crime = df_pivot_crime.reindex(index=['Spring','Summer','Fall','Winter'])
df_pivot_crime
# Out:
# Crime type  Anti-social behaviour  Bicycle theft  Burglary  \
# Season
# Spring                      84052           5689     12938
# Summer                      77427           6622     12776
# Fall                        77004           6444     14196
# Winter                      92339           3555     13083
#
# Crime type  Criminal damage and arson  Drugs  Other crime  Other theft  \
# Season
# Spring                          13523  11763         2752        18376
# Summer                          14372   9842         2491        24916
# Fall                            13536  11253         2802        24258
# Winter                          11623  11794         2284        15985
#
# Crime type  Possession of weapons  Public order  Robbery  Shoplifting  \
# Season
# Spring                       1181         16052     5191         8306
# Summer                       1268         17500     5731         9338
# Fall                         1408         15499     6838         8737
# ...

# %%
df_pivot_crime.plot()

plt.show()

# %%
df_pivot_outcome = pd.pivot_table(df, values='Reported by', index='Last outcome category', columns='Crime type',
                          aggfunc='count')

# %%
df_pivot_outcome
# Out:
# Crime type                                          Bicycle theft  Burglary  \
# Last outcome category
# Action to be taken by another organisation                    NaN       NaN
# Awaiting court outcome                                      115.0    1189.0
# Court result unavailable                                     60.0     698.0
# Formal action is not in the public interest                   1.0       1.0
# Further investigation is not in the public inte...            NaN       NaN
# Investigation complete; no suspect identified             18797.0   35419.0
# Local resolution                                             31.0      30.0
# Offender given a caution                                     23.0      46.0
# Offender given a drugs possession warning                     NaN       NaN
# Offender given penalty notice                                 NaN       2.0
# Status update unavailable                                   449.0    3839.0
# ...

# %%
df_pivot_location = pd.pivot_table(df, values='Reported by', index='Season', columns='Location type', aggfunc='count')

# %%
df_pivot_location
# Out:
# Location type  On Street  On or near Airport/Airfield  \
# Season
# Fall              232090                          257
# Spring            227968                          198
# Summer            230072                          228
# Winter            215255                          183
#
# Location type  On or near Bus/Coach Station  \
# Season
# Fall                                    580
# Spring                                  487
# Summer                                  547
# Winter                                  455
#
# Location type  On or near Conference/Exhibition Centre  \
# Season
# Fall                                               724
# Spring                                             629
# Summer                                             696
# Winter                                             642
#
# Location type  On or near Further/Higher Educational Building  \
# Season
# Fall                                                     1806
# ...

# %%
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20,15)

# %%
df_pivot_location.plot()

plt.show()

# %%
df_filt=df.loc[~df['Location type'].str.contains('On Street')]

# %%
df_filt
# Out:
#                                                   Crime ID       Month  \
# 1                                                      NaN  2021-06-01
# 6        906f1f72a297eb533d4f2ac6976c15e64b1da9ea060931...  2021-06-01
# 13       a592011f36c6d21fb970399e2f7d9ca4289dad50f2e272...  2021-06-01
# 20       6db34fbbaef2bc046d9c42c2d9386b179d571d37a4ece4...  2021-06-01
# 49       0a78162a59523bcfc3ba1c60ee27c3517cb4be770ec934...  2021-06-01
# ...                                                    ...         ...
# 1182889                                                NaN  2021-08-01
# 1182890                                                NaN  2021-08-01
# 1182891                                                NaN  2021-08-01
# 1182892                                                NaN  2021-08-01
# 1182893                                                NaN  2021-08-01
#
#                          Reported by                 Falls within  Longitude  \
# ...

# %%
df_pivot_location_filt = pd.pivot_table(df_filt, values='Reported by', index='Season', columns='Location type', aggfunc='count')

# %%
df_pivot_location_filt
# Out:
# Location type  On or near Airport/Airfield  On or near Bus/Coach Station  \
# Season
# Fall                                   257                           580
# Spring                                 198                           487
# Summer                                 228                           547
# Winter                                 183                           455
#
# Location type  On or near Conference/Exhibition Centre  \
# Season
# Fall                                               724
# Spring                                             629
# Summer                                             696
# Winter                                             642
#
# Location type  On or near Further/Higher Educational Building  \
# Season
# Fall                                                     1806
# Spring                                                   1495
# Summer                                                   1600
# ...

# %%
df_pivot_location_filt.plot()

plt.show()

# %%
ax = df_pivot_location.plot.bar(stacked=True, figsize=(8,6))
ax.set_ylim(0,300000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_pivot_crime_loc = pd.pivot_table(df_filt, values='Reported by', index='Location type', columns='Crime type',
                          aggfunc='count')

# %%
df_pivot_crime_loc
# Out:
# Crime type                                      Anti-social behaviour  \
# Location type
# On or near Airport/Airfield                                     294.0
# On or near Bus/Coach Station                                    596.0
# On or near Conference/Exhibition Centre                         768.0
# On or near Further/Higher Educational Building                 1716.0
# On or near Hospital                                             878.0
# On or near London Underground Station                             NaN
# On or near Meridian Square                                      117.0
# On or near Nightclub                                           1592.0
# On or near Park/Open Space                                      763.0
# On or near Parking Area                                        7215.0
# On or near Petrol Station                                      3565.0
# On or near Police Station                                      1521.0
# ...

# %%
ax = df_pivot_crime_loc.plot.bar(stacked=True, figsize=(15,20))
ax.set_ylim(0,42000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df_pivot_loc_crime = pd.pivot_table(df_filt, values='Reported by', index='Crime type', columns='Location type',
                          aggfunc='count')

# %%
df_pivot_loc_crime
# Out:
# Location type                 On or near Airport/Airfield  \
# Crime type
# Anti-social behaviour                               294.0
# Bicycle theft                                         1.0
# Burglary                                              2.0
# Criminal damage and arson                            11.0
# Drugs                                                16.0
# Other crime                                         265.0
# Other theft                                         232.0
# Possession of weapons                                 5.0
# Public order                                         46.0
# Robbery                                               2.0
# Shoplifting                                          19.0
# Theft from the person                                11.0
# Vehicle crime                                        17.0
# Violence and sexual offences                         75.0
#
# Location type                 On or near Bus/Coach Station  \
# Crime type
# ...

# %%
ax = df_pivot_loc_crime.plot.bar(stacked=True, figsize=(15,20))
ax.set_ylim(0,42000)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in all csv files that were downloaded from UK Police (see README).
path =r'C:\Users\Arne\Documents\TechLabs\TechLabs\Group project\Data'
filenames = glob.glob(path + "/*.csv")
dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))
    
# Concatenate all data into one DataFrame.
df = pd.concat(dfs, ignore_index=True)
df
# Out:
#                                                   Crime ID    Month  \
# 0                                                      NaN  2020-11
# 1                                                      NaN  2020-11
# 2                                                      NaN  2020-11
# 3                                                      NaN  2020-11
# 4                                                      NaN  2020-11
# ...                                                    ...      ...
# 1225158  66f48bd7adb6d6105c6bd6f420ee732dcda069da2a6d91...  2021-11
# 1225159  1689c1c09b215576a08f213df07e563c006450f17259fd...  2021-11
# 1225160  1f32c15e86bfd8e382fcc01923df5e180b3f2aa1f52850...  2021-11
# 1225161  16180f79523df2d23865782390eb7aa9cb15919962f380...  2021-11
# 1225162  cc19181a4f41872ed024d317bbd990d43dccf05ca36367...  2021-11
#
#                          Reported by                 Falls within  Longitude  \
# 0           British Transport Police     British Transport Police  -0.271604
# 1           British Transport Police     British Transport Police  -0.271604
# 2           British Transport Police     British Transport Police  -0.271604
# 3           British Transport Police     British Transport Police  -0.219532
# 4           British Transport Police     British Transport Police  -0.237124
# ...                              ...                          ...        ...
# 1225158  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225159  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225160  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225161  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225162  Metropolitan Police Service  Metropolitan Police Service        NaN
#
#          Latitude                              Location  LSOA code  LSOA name  \
# 0         50.8344  On or near Shoreham-By-Sea (Station)  E01031365  Adur 002D
# 1         50.8344  On or near Shoreham-By-Sea (Station)  E01031365  Adur 002D
# 2         50.8344  On or near Shoreham-By-Sea (Station)  E01031365  Adur 002D
# 3         50.8343      On or near Fishersgate (Station)  E01031348  Adur 004B
# 4         50.8325        On or near Southwick (Station)  E01031375  Adur 004G
# ...           ...                                   ...        ...        ...
# 1225158       NaN                           No Location        NaN        NaN
# 1225159       NaN                           No Location        NaN        NaN
# 1225160       NaN                           No Location        NaN        NaN
# 1225161       NaN                           No Location        NaN        NaN
# 1225162       NaN                           No Location        NaN        NaN
#
#                            Crime type  \
# 0           Criminal damage and arson
# 1                        Public order
# 2        Violence and sexual offences
# 3                         Other theft
# 4                               Drugs
# ...                               ...
# 1225158                   Other crime
# 1225159                   Other crime
# 1225160                   Other crime
# 1225161                   Other crime
# 1225162                   Other crime
#
#                                  Last outcome category  Context
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# ...                                                ...      ...
# 1225158                            Under investigation      NaN
# 1225159                            Under investigation      NaN
# 1225160                               Local resolution      NaN
# 1225161  Investigation complete; no suspect identified      NaN
# 1225162                            Under investigation      NaN
#
# [1225163 rows x 12 columns]

# %%
# We identified one spelling mistake in the raw data that will be removed with this line ("Staion" will be changed to "Station")
df['Location'].replace('On or near Shepherds Bush Market (Lu Staion)','On or near Shepherds Bush Market (Lu Station)',inplace=True)

# %%
# Add a new column called 'Location type' as a copy of the column 'Location' and display the DataFrame again.
df['Location type']=df['Location']
df
# Out:
#                                                   Crime ID    Month  \
# 0                                                      NaN  2020-11
# 1                                                      NaN  2020-11
# 2                                                      NaN  2020-11
# 3                                                      NaN  2020-11
# 4                                                      NaN  2020-11
# ...                                                    ...      ...
# 1225158  66f48bd7adb6d6105c6bd6f420ee732dcda069da2a6d91...  2021-11
# 1225159  1689c1c09b215576a08f213df07e563c006450f17259fd...  2021-11
# 1225160  1f32c15e86bfd8e382fcc01923df5e180b3f2aa1f52850...  2021-11
# 1225161  16180f79523df2d23865782390eb7aa9cb15919962f380...  2021-11
# 1225162  cc19181a4f41872ed024d317bbd990d43dccf05ca36367...  2021-11
#
#                          Reported by                 Falls within  Longitude  \
# 0           British Transport Police     British Transport Police  -0.271604
# 1           British Transport Police     British Transport Police  -0.271604
# 2           British Transport Police     British Transport Police  -0.271604
# 3           British Transport Police     British Transport Police  -0.219532
# 4           British Transport Police     British Transport Police  -0.237124
# ...                              ...                          ...        ...
# 1225158  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225159  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225160  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225161  Metropolitan Police Service  Metropolitan Police Service        NaN
# 1225162  Metropolitan Police Service  Metropolitan Police Service        NaN
#
#          Latitude                              Location  LSOA code  LSOA name  \
# 0         50.8344  On or near Shoreham-By-Sea (Station)  E01031365  Adur 002D
# 1         50.8344  On or near Shoreham-By-Sea (Station)  E01031365  Adur 002D
# 2         50.8344  On or near Shoreham-By-Sea (Station)  E01031365  Adur 002D
# 3         50.8343      On or near Fishersgate (Station)  E01031348  Adur 004B
# 4         50.8325        On or near Southwick (Station)  E01031375  Adur 004G
# ...           ...                                   ...        ...        ...
# 1225158       NaN                           No Location        NaN        NaN
# 1225159       NaN                           No Location        NaN        NaN
# 1225160       NaN                           No Location        NaN        NaN
# 1225161       NaN                           No Location        NaN        NaN
# 1225162       NaN                           No Location        NaN        NaN
#
#                            Crime type  \
# 0           Criminal damage and arson
# 1                        Public order
# 2        Violence and sexual offences
# 3                         Other theft
# 4                               Drugs
# ...                               ...
# 1225158                   Other crime
# 1225159                   Other crime
# 1225160                   Other crime
# 1225161                   Other crime
# 1225162                   Other crime
#
#                                  Last outcome category  Context  \
# 0                                                  NaN      NaN
# 1                                                  NaN      NaN
# 2                                                  NaN      NaN
# 3                                                  NaN      NaN
# 4                                                  NaN      NaN
# ...                                                ...      ...
# 1225158                            Under investigation      NaN
# 1225159                            Under investigation      NaN
# 1225160                               Local resolution      NaN
# 1225161  Investigation complete; no suspect identified      NaN
# 1225162                            Under investigation      NaN
#
#                                 Location type
# 0        On or near Shoreham-By-Sea (Station)
# 1        On or near Shoreham-By-Sea (Station)
# 2        On or near Shoreham-By-Sea (Station)
# 3            On or near Fishersgate (Station)
# 4              On or near Southwick (Station)
# ...                                       ...
# 1225158                           No Location
# 1225159                           No Location
# 1225160                           No Location
# 1225161                           No Location
# 1225162                           No Location
#
# [1225163 rows x 13 columns]

# %%
# Change the data type of 'Location type' to string.
df['Location type'] = df['Location type'].astype('string')

# %%
# Check if it worked out.
df.dtypes['Location type']
# Out:
# StringDtype

# %%
# Define the coordinates that frame the area Greater London.
lat_max=(df['Latitude']<51.691536)
lat_min=(df['Latitude']>51.291436341041205)
lon_max=(df['Longitude']<0.3337516278548758)
lon_min=(df['Longitude']>-0.5135695653558527)

# %%
# Filter crimes which are lying in the selected area.
df_filt=df.loc[lat_min & lat_max & lon_min & lon_max]

# %%
# Display the filtered DataFrame.
df_filt
# Out:
#                                                   Crime ID    Month  \
# 47                                                     NaN  2020-11
# 48                                                     NaN  2020-11
# 49                                                     NaN  2020-11
# 50                                                     NaN  2020-11
# 51                                                     NaN  2020-11
# ...                                                    ...      ...
# 1222979                                                NaN  2021-11
# 1222980  acd8db739e8af3a66db17a6f647f6d3ec07e1ee5e3c7d8...  2021-11
# 1222981  553f1cb4a93779a7a65786fd892e914eef5355707df2c8...  2021-11
# 1222982  6fc3285734ef0a6964634f9cf1a20e66e61996d4a3ecc1...  2021-11
# 1222985  e73312694fa6fb4b7b6ec8c8801f308154f469ce1ae5df...  2021-11
#
#                          Reported by                 Falls within  Longitude  \
# 47          British Transport Police     British Transport Police   0.132018
# 48          British Transport Police     British Transport Police   0.165776
# 49          British Transport Police     British Transport Police   0.165776
# 50          British Transport Police     British Transport Police   0.165776
# 51          British Transport Police     British Transport Police   0.101517
# ...                              ...                          ...        ...
# 1222979  Metropolitan Police Service  Metropolitan Police Service  -0.134554
# 1222980  Metropolitan Police Service  Metropolitan Police Service  -0.134554
# 1222981  Metropolitan Police Service  Metropolitan Police Service  -0.135532
# 1222982  Metropolitan Police Service  Metropolitan Police Service  -0.135532
# 1222985  Metropolitan Police Service  Metropolitan Police Service  -0.480873
#
#           Latitude                               Location  LSOA code  \
# 47       51.568053    On or near Chadwell Heath (Station)  E01000112
# 48       51.544200  On or near Dagenham East (Lu Station)  E01000036
# 49       51.544200  On or near Dagenham East (Lu Station)  E01000036
# 50       51.544200  On or near Dagenham East (Lu Station)  E01000036
# 51       51.538397          On or near Upney (Lu Station)  E01000071
# ...            ...                                    ...        ...
# 1222979  51.490475              On or near Garden Terrace  E01004741
# 1222980  51.490475              On or near Garden Terrace  E01004741
# 1222981  51.489097          On or near St George'S Square  E01004741
# 1222982  51.489097          On or near St George'S Square  E01004741
# 1222985  51.342828               On or near Chertsey Road  E01030949
#
#                          LSOA name                    Crime type  \
# 47       Barking and Dagenham 002E                 Bicycle theft
# 48       Barking and Dagenham 010B                  Public order
# 49       Barking and Dagenham 010B         Theft from the person
# 50       Barking and Dagenham 010B         Theft from the person
# 51       Barking and Dagenham 011E     Criminal damage and arson
# ...                            ...                           ...
# 1222979           Westminster 024F         Anti-social behaviour
# 1222980           Westminster 024F                         Drugs
# 1222981           Westminster 024F  Violence and sexual offences
# 1222982           Westminster 024F  Violence and sexual offences
# 1222985                Woking 001D  Violence and sexual offences
#
#                                  Last outcome category  Context  \
# 47                                                 NaN      NaN
# 48                                                 NaN      NaN
# 49                                                 NaN      NaN
# 50                                                 NaN      NaN
# 51                                                 NaN      NaN
# ...                                                ...      ...
# 1222979                                            NaN      NaN
# 1222980                         Awaiting court outcome      NaN
# 1222981  Investigation complete; no suspect identified      NaN
# 1222982                            Under investigation      NaN
# 1222985                            Under investigation      NaN
#
#                                  Location type
# 47         On or near Chadwell Heath (Station)
# 48       On or near Dagenham East (Lu Station)
# 49       On or near Dagenham East (Lu Station)
# 50       On or near Dagenham East (Lu Station)
# 51               On or near Upney (Lu Station)
# ...                                        ...
# 1222979              On or near Garden Terrace
# 1222980              On or near Garden Terrace
# 1222981          On or near St George'S Square
# 1222982          On or near St George'S Square
# 1222985               On or near Chertsey Road
#
# [1183961 rows x 13 columns]

# %%
# Create a seperate DataFrame called 'df_bt' which only contains the crimes that were reported by British Transport Police.
df_bt=df_filt.loc[df_filt['Reported by']=='British Transport Police']

# %%
df_bt
# Out:
#         Crime ID    Month               Reported by              Falls within  \
# 47           NaN  2020-11  British Transport Police  British Transport Police
# 48           NaN  2020-11  British Transport Police  British Transport Police
# 49           NaN  2020-11  British Transport Police  British Transport Police
# 50           NaN  2020-11  British Transport Police  British Transport Police
# 51           NaN  2020-11  British Transport Police  British Transport Police
# ...          ...      ...                       ...                       ...
# 1133944      NaN  2021-11  British Transport Police  British Transport Police
# 1133945      NaN  2021-11  British Transport Police  British Transport Police
# 1133946      NaN  2021-11  British Transport Police  British Transport Police
# 1134015      NaN  2021-11  British Transport Police  British Transport Police
# 1134016      NaN  2021-11  British Transport Police  British Transport Police
#
#          Longitude   Latitude                               Location  \
# 47        0.132018  51.568053    On or near Chadwell Heath (Station)
# 48        0.165776  51.544200  On or near Dagenham East (Lu Station)
# 49        0.165776  51.544200  On or near Dagenham East (Lu Station)
# 50        0.165776  51.544200  On or near Dagenham East (Lu Station)
# 51        0.101517  51.538397          On or near Upney (Lu Station)
# ...            ...        ...                                    ...
# 1133944  -0.133463  51.489300        On or near Pimlico (Lu Station)
# 1133945  -0.133463  51.489300        On or near Pimlico (Lu Station)
# 1133946  -0.133463  51.489300        On or near Pimlico (Lu Station)
# 1134015  -0.505346  51.339500      On or near West Byfleet (Station)
# 1134016  -0.505346  51.339500      On or near West Byfleet (Station)
#
#          LSOA code                  LSOA name                    Crime type  \
# 47       E01000112  Barking and Dagenham 002E                 Bicycle theft
# 48       E01000036  Barking and Dagenham 010B                  Public order
# 49       E01000036  Barking and Dagenham 010B         Theft from the person
# 50       E01000036  Barking and Dagenham 010B         Theft from the person
# 51       E01000071  Barking and Dagenham 011E     Criminal damage and arson
# ...            ...                        ...                           ...
# 1133944  E01004741           Westminster 024F         Theft from the person
# 1133945  E01004741           Westminster 024F         Theft from the person
# 1133946  E01004741           Westminster 024F         Theft from the person
# 1134015  E01031004                Woking 002E                  Public order
# 1134016  E01031004                Woking 002E  Violence and sexual offences
#
#         Last outcome category  Context                          Location type
# 47                        NaN      NaN    On or near Chadwell Heath (Station)
# 48                        NaN      NaN  On or near Dagenham East (Lu Station)
# 49                        NaN      NaN  On or near Dagenham East (Lu Station)
# 50                        NaN      NaN  On or near Dagenham East (Lu Station)
# 51                        NaN      NaN          On or near Upney (Lu Station)
# ...                       ...      ...                                    ...
# 1133944                   NaN      NaN        On or near Pimlico (Lu Station)
# 1133945                   NaN      NaN        On or near Pimlico (Lu Station)
# 1133946                   NaN      NaN        On or near Pimlico (Lu Station)
# 1134015                   NaN      NaN      On or near West Byfleet (Station)
# 1134016                   NaN      NaN      On or near West Byfleet (Station)
#
# [19626 rows x 13 columns]

# %%
# Clean the DataFrame 'df_filt' from the crimes which were reported by British Transport Police to cluster the Location types in both new DataFrames seperately.
df_filt.drop(df_filt.loc[df_filt['Reported by']=='British Transport Police'].index, inplace=True)
# Out:
# C:\Users\Arne\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_filt
# Out:
#                                                   Crime ID    Month  \
# 3129                                                   NaN  2020-11
# 3130     11ee4f5a06a401f7adb6b08b1952502a9726b72a80e3bf...  2020-11
# 3131     c59fa822e4291221edb6dcaa7de6032f5c67b51ab3fc89...  2020-11
# 3132     e39b097f0f5121b8c3887d26867154d621ce209bfa284f...  2020-11
# 3133     41385bb4b1b7637bf52594ef105e65cf535e6c7b7c01fc...  2020-11
# ...                                                    ...      ...
# 1222979                                                NaN  2021-11
# 1222980  acd8db739e8af3a66db17a6f647f6d3ec07e1ee5e3c7d8...  2021-11
# 1222981  553f1cb4a93779a7a65786fd892e914eef5355707df2c8...  2021-11
# 1222982  6fc3285734ef0a6964634f9cf1a20e66e61996d4a3ecc1...  2021-11
# 1222985  e73312694fa6fb4b7b6ec8c8801f308154f469ce1ae5df...  2021-11
#
#                          Reported by                 Falls within  Longitude  \
# 3129           City of London Police        City of London Police  -0.098572
# 3130           City of London Police        City of London Police  -0.097736
# 3131           City of London Police        City of London Police  -0.097334
# 3132           City of London Police        City of London Police  -0.097601
# 3133           City of London Police        City of London Police  -0.098572
# ...                              ...                          ...        ...
# 1222979  Metropolitan Police Service  Metropolitan Police Service  -0.134554
# 1222980  Metropolitan Police Service  Metropolitan Police Service  -0.134554
# 1222981  Metropolitan Police Service  Metropolitan Police Service  -0.135532
# 1222982  Metropolitan Police Service  Metropolitan Police Service  -0.135532
# 1222985  Metropolitan Police Service  Metropolitan Police Service  -0.480873
#
#           Latitude                                 Location  LSOA code  \
# 3129     51.516767            On or near King Edward Street  E01000001
# 3130     51.520206  On or near Conference/Exhibition Centre  E01000001
# 3131     51.521567                   On or near Fann Street  E01000001
# 3132     51.520699             On or near Carthusian Street  E01000001
# 3133     51.516767            On or near King Edward Street  E01000001
# ...            ...                                      ...        ...
# 1222979  51.490475                On or near Garden Terrace  E01004741
# 1222980  51.490475                On or near Garden Terrace  E01004741
# 1222981  51.489097            On or near St George'S Square  E01004741
# 1222982  51.489097            On or near St George'S Square  E01004741
# 1222985  51.342828                 On or near Chertsey Road  E01030949
#
#                    LSOA name                    Crime type  \
# 3129     City of London 001A         Anti-social behaviour
# 3130     City of London 001A                 Bicycle theft
# 3131     City of London 001A                      Burglary
# 3132     City of London 001A                         Drugs
# 3133     City of London 001A                   Other theft
# ...                      ...                           ...
# 1222979     Westminster 024F         Anti-social behaviour
# 1222980     Westminster 024F                         Drugs
# 1222981     Westminster 024F  Violence and sexual offences
# 1222982     Westminster 024F  Violence and sexual offences
# 1222985          Woking 001D  Violence and sexual offences
#
#                                  Last outcome category  Context  \
# 3129                                               NaN      NaN
# 3130     Investigation complete; no suspect identified      NaN
# 3131     Investigation complete; no suspect identified      NaN
# 3132         Offender given a drugs possession warning      NaN
# 3133     Investigation complete; no suspect identified      NaN
# ...                                                ...      ...
# 1222979                                            NaN      NaN
# 1222980                         Awaiting court outcome      NaN
# 1222981  Investigation complete; no suspect identified      NaN
# 1222982                            Under investigation      NaN
# 1222985                            Under investigation      NaN
#
#                                    Location type
# 3129               On or near King Edward Street
# 3130     On or near Conference/Exhibition Centre
# 3131                      On or near Fann Street
# 3132                On or near Carthusian Street
# 3133               On or near King Edward Street
# ...                                          ...
# 1222979                On or near Garden Terrace
# 1222980                On or near Garden Terrace
# 1222981            On or near St George'S Square
# 1222982            On or near St George'S Square
# 1222985                 On or near Chertsey Road
#
# [1164335 rows x 13 columns]

# %%
# In the DataFrame 'df_filt' cluster all locations that happened on any streets in Greater London into the Location type 'On Street'.
df_filt.loc[~df_filt['Location type'].str.contains('On or near Supermarket|On or near Parking Area|On or near Shopping Area|On or near Petrol Station|On or near Sports/Recreation Area|No Location|On or near Nightclub|On or near Pedestrian Subway|On or near Further/Higher Educational Building|On or near Hospital|On or near Police Station|On or near Theatre/Concert Hall|On or near Conference/Exhibition Centre|On or near Park/Open Space|On or near Bus/Coach Station|On or near Meridian Square|On or near Airport/Airfield'), 'Location type'] = 'On Street'
# Out:
# C:\Users\Arne\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# Show all values of Location type and their counts in the DataFrame 'df_filt'.
df_filt['Location type'].value_counts()
# Out:
# On Street                                         977215
# On or near Supermarket                             40298
# On or near Parking Area                            29104
# On or near Shopping Area                           25116
# On or near Petrol Station                          18966
# On or near Sports/Recreation Area                  15864
# On or near Nightclub                               10524
# On or near Pedestrian Subway                       10096
# On or near Further/Higher Educational Building      6900
# On or near Hospital                                 6638
# On or near Police Station                           6488
# On or near Theatre/Concert Hall                     6335
# On or near Conference/Exhibition Centre             2925
# On or near Park/Open Space                          2475
# On or near Bus/Coach Station                        2261
# On or near Meridian Square                          1989
# On or near Airport/Airfield                          996
# On or near Hospital Road                             117
# On or near Hospital Bridge Road                       23
# On or near Hospital Way                                5
# Name: Location type, dtype: Int64

# %%
# Replace the Location type 'On or near Pedestrian Subway' with the name 'On or near Underpass'.
df_filt['Location type'].replace('On or near Pedestrian Subway','On or near Underpass',inplace=True)
# Out:
# C:\Users\Arne\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
# There are still three street names that include the word hospital that weren't included in the Location type 'On Street' due to that. Replace these three street names with the Location type 'On Street'.
df_filt['Location type'].replace('On or near Hospital Road','On Street',inplace=True)

# %%
df_filt['Location type'].replace('On or near Hospital Bridge Road','On Street',inplace=True)

# %%
df_filt['Location type'].replace('On or near Hospital Way','On Street',inplace=True)

# %%
# Show again all values of Location type and their counts in the DataFrame 'df_filt' to see if the clustering is now correct (just Location types and no single street names left).
df_filt['Location type'].value_counts()
# Out:
# On Street                                         977360
# On or near Supermarket                             40298
# On or near Parking Area                            29104
# On or near Shopping Area                           25116
# On or near Petrol Station                          18966
# On or near Sports/Recreation Area                  15864
# On or near Nightclub                               10524
# On or near Underpass                               10096
# On or near Further/Higher Educational Building      6900
# On or near Hospital                                 6638
# On or near Police Station                           6488
# On or near Theatre/Concert Hall                     6335
# On or near Conference/Exhibition Centre             2925
# On or near Park/Open Space                          2475
# On or near Bus/Coach Station                        2261
# On or near Meridian Square                          1989
# On or near Airport/Airfield                          996
# Name: Location type, dtype: Int64

# %%
# In the DataFrame 'df_bt' cluster all locations that happened in any London Underground Stations (Lu Station) in Greater London into the Location type 'On or near London Underground Station'.
df_bt.loc[df_bt['Location type'].str.contains('Lu Station'), 'Location type'] = 'On or near London Underground Station'

# %%
# Show all values of Location type and their counts in the DataFrame 'df_bt'.
df_bt['Location type'].value_counts().head(60)
# Out:
# On or near London Underground Station                         7872
# On or near London Bridge (Station)                             507
# On or near St  Pancras International (Station)                 496
# On or near Stratford (Station)                                 475
# On or near Kings Cross (Station)                               426
# On or near Waterloo  (London) (Station)                        419
# On or near Paddington (Station)                                386
# On or near Liverpool Street (Station)                          372
# On or near Finsbury Park (Station)                             359
# On or near Clapham Junction (Station)                          311
# On or near East Croydon (Station)                              259
# On or near Dartford (Station)                                  157
# On or near Charing Cross (Station)                             153
# On or near Barking (Station)                                   152
# On or near Vauxhall (Station)                                  151
# On or near West Ham (Dlr)                                      133
# On or near Woolwich Arsenal (Station)                          132
# On or near Highbury And Islington (Station)                    132
# On or near Euston (Station)                                    121
# On or near Tottenham Hale (Station)                            116
# On or near Watford Junction (Station)                          112
# On or near Bromley South (Station)                             103
# On or near Wimbledon (Station)                                  95
# On or near Stratford International (Station)                    89
# On or near Richmond (Station)                                   85
# On or near Surbiton (Station)                                   83
# On or near Orpington (Station)                                  74
# On or near Marylebone (Station)                                 74
# On or near Lewisham (Station)                                   73
# On or near Grays (Station)                                      70
# On or near Plumstead (Station)                                  69
# On or near Upminster (Station)                                  68
# On or near Blackfriars (Station)                                64
# On or near Swanley (Station)                                    64
# On or near West Croydon (Station)                               62
# On or near Staines (Station)                                    60
# On or near Walton-On-Thames (Station)                           58
# On or near Romford (Station)                                    58
# On or near North Greenwich Transport Interchange (Station)      57
# On or near Ilford (Station)                                     55
# On or near Sutton (Surrey) (Station)                            54
# On or near Epsom (Station)                                      52
# On or near Shenfield (Station)                                  51
# On or near Peckham Rye (Station)                                50
# On or near Maidenhead (Station)                                 48
# On or near Grove Park (Station)                                 47
# On or near Ebbsfleet International (Station)                    47
# On or near St Mary Cray (Station)                               45
# On or near Ealing Broadway (Station)                            45
# On or near Shadwell (Dlr)                                       44
# On or near Feltham (Station)                                    42
# On or near Twickenham (Station)                                 42
# On or near Elstree And Borehamwood (Station)                    42
# On or near West Ham (Station)                                   41
# On or near Farringdon (Station)                                 38
# On or near Chadwell Heath (Station)                             37
# On or near Dalston Junction (Station)                           37
# On or near Goodmayes (Station)                                  35
# On or near Elephant And Castle (Station)                        34
# On or near Willesden Junction (Station)                         34
# Name: Location type, dtype: Int64

# %%
# In the DataFrame 'df_bt' cluster all locations that happened in any Train Station (Station) or at a Tram Stop in Greater London into the Location type 'On or near Train Station/Tram Stop'.
df_bt.loc[~df_bt['Location type'].str.contains('On or near London Underground Station'), 'Location type'] = 'On or near Train Station/Tram Stop'

# %%
# Show again all values of Location type and their counts in the DataFrame 'df_bt'.
df_bt['Location type'].value_counts()
# Out:
# On or near Train Station/Tram Stop       11754
# On or near London Underground Station     7872
# Name: Location type, dtype: Int64

# %%
# Concatenate the two DataFrames 'df_filt' and 'df_bt' into one DataFrame called 'df'.
df = pd.concat([df_filt, df_bt], ignore_index=True, sort=False)

# %%
df
# Out:
#                                                   Crime ID    Month  \
# 0                                                      NaN  2020-11
# 1        11ee4f5a06a401f7adb6b08b1952502a9726b72a80e3bf...  2020-11
# 2        c59fa822e4291221edb6dcaa7de6032f5c67b51ab3fc89...  2020-11
# 3        e39b097f0f5121b8c3887d26867154d621ce209bfa284f...  2020-11
# 4        41385bb4b1b7637bf52594ef105e65cf535e6c7b7c01fc...  2020-11
# ...                                                    ...      ...
# 1183956                                                NaN  2021-11
# 1183957                                                NaN  2021-11
# 1183958                                                NaN  2021-11
# 1183959                                                NaN  2021-11
# 1183960                                                NaN  2021-11
#
#                       Reported by              Falls within  Longitude  \
# 0           City of London Police     City of London Police  -0.098572
# 1           City of London Police     City of London Police  -0.097736
# 2           City of London Police     City of London Police  -0.097334
# 3           City of London Police     City of London Police  -0.097601
# 4           City of London Police     City of London Police  -0.098572
# ...                           ...                       ...        ...
# 1183956  British Transport Police  British Transport Police  -0.133463
# 1183957  British Transport Police  British Transport Police  -0.133463
# 1183958  British Transport Police  British Transport Police  -0.133463
# 1183959  British Transport Police  British Transport Police  -0.505346
# 1183960  British Transport Police  British Transport Police  -0.505346
#
#           Latitude                                 Location  LSOA code  \
# 0        51.516767            On or near King Edward Street  E01000001
# 1        51.520206  On or near Conference/Exhibition Centre  E01000001
# 2        51.521567                   On or near Fann Street  E01000001
# 3        51.520699             On or near Carthusian Street  E01000001
# 4        51.516767            On or near King Edward Street  E01000001
# ...            ...                                      ...        ...
# 1183956  51.489300          On or near Pimlico (Lu Station)  E01004741
# 1183957  51.489300          On or near Pimlico (Lu Station)  E01004741
# 1183958  51.489300          On or near Pimlico (Lu Station)  E01004741
# 1183959  51.339500        On or near West Byfleet (Station)  E01031004
# 1183960  51.339500        On or near West Byfleet (Station)  E01031004
#
#                    LSOA name                    Crime type  \
# 0        City of London 001A         Anti-social behaviour
# 1        City of London 001A                 Bicycle theft
# 2        City of London 001A                      Burglary
# 3        City of London 001A                         Drugs
# 4        City of London 001A                   Other theft
# ...                      ...                           ...
# 1183956     Westminster 024F         Theft from the person
# 1183957     Westminster 024F         Theft from the person
# 1183958     Westminster 024F         Theft from the person
# 1183959          Woking 002E                  Public order
# 1183960          Woking 002E  Violence and sexual offences
#
#                                  Last outcome category  Context  \
# 0                                                  NaN      NaN
# 1        Investigation complete; no suspect identified      NaN
# 2        Investigation complete; no suspect identified      NaN
# 3            Offender given a drugs possession warning      NaN
# 4        Investigation complete; no suspect identified      NaN
# ...                                                ...      ...
# 1183956                                            NaN      NaN
# 1183957                                            NaN      NaN
# 1183958                                            NaN      NaN
# 1183959                                            NaN      NaN
# 1183960                                            NaN      NaN
#
#                                    Location type
# 0                                      On Street
# 1        On or near Conference/Exhibition Centre
# 2                                      On Street
# 3                                      On Street
# 4                                      On Street
# ...                                          ...
# 1183956    On or near London Underground Station
# 1183957    On or near London Underground Station
# 1183958    On or near London Underground Station
# 1183959       On or near Train Station/Tram Stop
# 1183960       On or near Train Station/Tram Stop
#
# [1183961 rows x 13 columns]

# %%
df.dtypes
# Out:
# Crime ID                  object
# Month                     object
# Reported by               object
# Falls within              object
# Longitude                float64
# Latitude                 float64
# Location                  object
# LSOA code                 object
# LSOA name                 object
# Crime type                object
# Last outcome category     object
# Context                  float64
# Location type             string
# dtype: object

# %%
import numpy as np

# %%
# Check the type of "Month" data - string or number.
df.loc[0,'Month']
# Out:
# '2020-11'

# %%
# Covert the type of data in month to year-month.
df['Month'] = pd.to_datetime(df['Month'],format = '%Y-%m')
df.head(5)
# Out:
#                                             Crime ID      Month  \
# 0                                                NaN 2020-11-01
# 1  11ee4f5a06a401f7adb6b08b1952502a9726b72a80e3bf... 2020-11-01
# 2  c59fa822e4291221edb6dcaa7de6032f5c67b51ab3fc89... 2020-11-01
# 3  e39b097f0f5121b8c3887d26867154d621ce209bfa284f... 2020-11-01
# 4  41385bb4b1b7637bf52594ef105e65cf535e6c7b7c01fc... 2020-11-01
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.098572  51.516767
# 1  City of London Police  City of London Police  -0.097736  51.520206
# 2  City of London Police  City of London Police  -0.097334  51.521567
# 3  City of London Police  City of London Police  -0.097601  51.520699
# 4  City of London Police  City of London Police  -0.098572  51.516767
#
#                                   Location  LSOA code            LSOA name  \
# 0            On or near King Edward Street  E01000001  City of London 001A
# 1  On or near Conference/Exhibition Centre  E01000001  City of London 001A
# 2                   On or near Fann Street  E01000001  City of London 001A
# 3             On or near Carthusian Street  E01000001  City of London 001A
# 4            On or near King Edward Street  E01000001  City of London 001A
#
#               Crime type                          Last outcome category  \
# 0  Anti-social behaviour                                            NaN
# 1          Bicycle theft  Investigation complete; no suspect identified
# 2               Burglary  Investigation complete; no suspect identified
# 3                  Drugs      Offender given a drugs possession warning
# 4            Other theft  Investigation complete; no suspect identified
#
#    Context                            Location type
# 0      NaN                                On Street
# 1      NaN  On or near Conference/Exhibition Centre
# 2      NaN                                On Street
# 3      NaN                                On Street
# 4      NaN                                On Street

# %%
# Check the values, if they were converted or not.
df['Month']
# Out:
# 0         2020-11-01
# 1         2020-11-01
# 2         2020-11-01
# 3         2020-11-01
# 4         2020-11-01
#              ...
# 1183956   2021-11-01
# 1183957   2021-11-01
# 1183958   2021-11-01
# 1183959   2021-11-01
# 1183960   2021-11-01
# Name: Month, Length: 1183961, dtype: datetime64[ns]

# %%
# Add new column - "Season"
df['Season'] = ''

# %%
# Check if it was added
df.tail(5)
# Out:
#         Crime ID      Month               Reported by  \
# 1183956      NaN 2021-11-01  British Transport Police
# 1183957      NaN 2021-11-01  British Transport Police
# 1183958      NaN 2021-11-01  British Transport Police
# 1183959      NaN 2021-11-01  British Transport Police
# 1183960      NaN 2021-11-01  British Transport Police
#
#                      Falls within  Longitude  Latitude  \
# 1183956  British Transport Police  -0.133463   51.4893
# 1183957  British Transport Police  -0.133463   51.4893
# 1183958  British Transport Police  -0.133463   51.4893
# 1183959  British Transport Police  -0.505346   51.3395
# 1183960  British Transport Police  -0.505346   51.3395
#
#                                   Location  LSOA code         LSOA name  \
# 1183956    On or near Pimlico (Lu Station)  E01004741  Westminster 024F
# 1183957    On or near Pimlico (Lu Station)  E01004741  Westminster 024F
# 1183958    On or near Pimlico (Lu Station)  E01004741  Westminster 024F
# 1183959  On or near West Byfleet (Station)  E01031004       Woking 002E
# 1183960  On or near West Byfleet (Station)  E01031004       Woking 002E
#
#                            Crime type Last outcome category  Context  \
# 1183956         Theft from the person                   NaN      NaN
# 1183957         Theft from the person                   NaN      NaN
# 1183958         Theft from the person                   NaN      NaN
# 1183959                  Public order                   NaN      NaN
# 1183960  Violence and sexual offences                   NaN      NaN
#
#                                  Location type Season
# 1183956  On or near London Underground Station
# 1183957  On or near London Underground Station
# 1183958  On or near London Underground Station
# 1183959     On or near Train Station/Tram Stop
# 1183960     On or near Train Station/Tram Stop

# %%
# Set all values during this period as "Winter" in the table Season
df.loc[df['Month'] == '2020-12','Season'] = 'Winter'
df.loc[df['Month'] == '2021-01','Season'] = 'Winter'
df.loc[df['Month'] == '2021-02','Season'] = 'Winter'

# %%
# Set all values during this period as "Spring" in the table Season
df.loc[df['Month'] == '2021-03','Season'] = 'Spring'
df.loc[df['Month'] == '2021-04','Season'] = 'Spring'
df.loc[df['Month'] == '2021-05','Season'] = 'Spring'

# %%
# Set all values during this period as "Summer" in the table Season
df.loc[df['Month'] == '2021-06','Season'] = 'Summer'
df.loc[df['Month'] == '2021-07','Season'] = 'Summer'
df.loc[df['Month'] == '2021-08','Season'] = 'Summer'

# %%
# Set all values during this period as "Fall" in the table Season
df.loc[df['Month'] == '2021-09','Season'] = 'Fall'
df.loc[df['Month'] == '2021-10','Season'] = 'Fall'
df.loc[df['Month'] == '2020-11','Season'] = 'Fall'

# %%
df['Season']
# Out:
# 0          Fall
# 1          Fall
# 2          Fall
# 3          Fall
# 4          Fall
#            ...
# 1183956
# 1183957
# 1183958
# 1183959
# 1183960
# Name: Season, Length: 1183961, dtype: object

# %%
df
# Out:
#                                                   Crime ID      Month  \
# 0                                                      NaN 2020-11-01
# 1        11ee4f5a06a401f7adb6b08b1952502a9726b72a80e3bf... 2020-11-01
# 2        c59fa822e4291221edb6dcaa7de6032f5c67b51ab3fc89... 2020-11-01
# 3        e39b097f0f5121b8c3887d26867154d621ce209bfa284f... 2020-11-01
# 4        41385bb4b1b7637bf52594ef105e65cf535e6c7b7c01fc... 2020-11-01
# ...                                                    ...        ...
# 1183956                                                NaN 2021-11-01
# 1183957                                                NaN 2021-11-01
# 1183958                                                NaN 2021-11-01
# 1183959                                                NaN 2021-11-01
# 1183960                                                NaN 2021-11-01
#
#                       Reported by              Falls within  Longitude  \
# 0           City of London Police     City of London Police  -0.098572
# 1           City of London Police     City of London Police  -0.097736
# 2           City of London Police     City of London Police  -0.097334
# 3           City of London Police     City of London Police  -0.097601
# 4           City of London Police     City of London Police  -0.098572
# ...                           ...                       ...        ...
# 1183956  British Transport Police  British Transport Police  -0.133463
# 1183957  British Transport Police  British Transport Police  -0.133463
# 1183958  British Transport Police  British Transport Police  -0.133463
# 1183959  British Transport Police  British Transport Police  -0.505346
# 1183960  British Transport Police  British Transport Police  -0.505346
#
#           Latitude                                 Location  LSOA code  \
# 0        51.516767            On or near King Edward Street  E01000001
# 1        51.520206  On or near Conference/Exhibition Centre  E01000001
# 2        51.521567                   On or near Fann Street  E01000001
# 3        51.520699             On or near Carthusian Street  E01000001
# 4        51.516767            On or near King Edward Street  E01000001
# ...            ...                                      ...        ...
# 1183956  51.489300          On or near Pimlico (Lu Station)  E01004741
# 1183957  51.489300          On or near Pimlico (Lu Station)  E01004741
# 1183958  51.489300          On or near Pimlico (Lu Station)  E01004741
# 1183959  51.339500        On or near West Byfleet (Station)  E01031004
# 1183960  51.339500        On or near West Byfleet (Station)  E01031004
#
#                    LSOA name                    Crime type  \
# 0        City of London 001A         Anti-social behaviour
# 1        City of London 001A                 Bicycle theft
# 2        City of London 001A                      Burglary
# 3        City of London 001A                         Drugs
# 4        City of London 001A                   Other theft
# ...                      ...                           ...
# 1183956     Westminster 024F         Theft from the person
# 1183957     Westminster 024F         Theft from the person
# 1183958     Westminster 024F         Theft from the person
# 1183959          Woking 002E                  Public order
# 1183960          Woking 002E  Violence and sexual offences
#
#                                  Last outcome category  Context  \
# 0                                                  NaN      NaN
# 1        Investigation complete; no suspect identified      NaN
# 2        Investigation complete; no suspect identified      NaN
# 3            Offender given a drugs possession warning      NaN
# 4        Investigation complete; no suspect identified      NaN
# ...                                                ...      ...
# 1183956                                            NaN      NaN
# 1183957                                            NaN      NaN
# 1183958                                            NaN      NaN
# 1183959                                            NaN      NaN
# 1183960                                            NaN      NaN
#
#                                    Location type Season
# 0                                      On Street   Fall
# 1        On or near Conference/Exhibition Centre   Fall
# 2                                      On Street   Fall
# 3                                      On Street   Fall
# 4                                      On Street   Fall
# ...                                          ...    ...
# 1183956    On or near London Underground Station
# 1183957    On or near London Underground Station
# 1183958    On or near London Underground Station
# 1183959       On or near Train Station/Tram Stop
# 1183960       On or near Train Station/Tram Stop
#
# [1183961 rows x 14 columns]

# %%
filt = (df['Season'] == 'Spring')
df[filt]
# Out:
#                                                   Crime ID      Month  \
# 348736   59263678a3b555ff49b56c8139a50ae7d726319ad11696... 2021-03-01
# 348737   b76e47ab9e47e04e113d39a07e5d98ebe26573e2e59c87... 2021-03-01
# 348738   eb03022d768846e0205cb1085ac26f657d522b5d391779... 2021-03-01
# 348739   cb8731ed3a2baf3ea4bb652a2049b3bc407dbbf73d19ee... 2021-03-01
# 348740   51e6cadbbe32c9edcd77d9be18ab0bf0e133e07d026b54... 2021-03-01
# ...                                                    ...        ...
# 1173195                                                NaN 2021-05-01
# 1173196                                                NaN 2021-05-01
# 1173197                                                NaN 2021-05-01
# 1173198                                                NaN 2021-05-01
# 1173199                                                NaN 2021-05-01
#
#                       Reported by              Falls within  Longitude  \
# 348736      City of London Police     City of London Police  -0.126375
# 348737      City of London Police     City of London Police  -0.109582
# 348738      City of London Police     City of London Police  -0.109582
# 348739      City of London Police     City of London Police  -0.111497
# 348740      City of London Police     City of London Police  -0.111497
# ...                           ...                       ...        ...
# 1173195  British Transport Police  British Transport Police  -0.133463
# 1173196  British Transport Police  British Transport Police  -0.505346
# 1173197  British Transport Police  British Transport Police  -0.505346
# 1173198  British Transport Police  British Transport Police  -0.505346
# 1173199  British Transport Police  British Transport Police  -0.505346
#
#           Latitude                           Location  LSOA code  \
# 348736   51.531512           On or near Shopping Area  E01000953
# 348737   51.522017        On or near Clerkenwell Road  E01000916
# 348738   51.522017        On or near Clerkenwell Road  E01000916
# 348739   51.518226       On or near Pedestrian Subway  E01000914
# 348740   51.518226       On or near Pedestrian Subway  E01000914
# ...            ...                                ...        ...
# 1173195  51.489300    On or near Pimlico (Lu Station)  E01004741
# 1173196  51.339500  On or near West Byfleet (Station)  E01031004
# 1173197  51.339500  On or near West Byfleet (Station)  E01031004
# 1173198  51.339500  On or near West Byfleet (Station)  E01031004
# 1173199  51.339500  On or near West Byfleet (Station)  E01031004
#
#                 LSOA name                    Crime type  \
# 348736        Camden 022B  Violence and sexual offences
# 348737        Camden 027B                         Drugs
# 348738        Camden 027B         Possession of weapons
# 348739        Camden 028B                      Burglary
# 348740        Camden 028B                   Other theft
# ...                   ...                           ...
# 1173195  Westminster 024F         Theft from the person
# 1173196       Woking 002E                 Bicycle theft
# 1173197       Woking 002E                 Bicycle theft
# 1173198       Woking 002E                 Bicycle theft
# 1173199       Woking 002E                 Bicycle theft
#
#                                  Last outcome category  Context  \
# 348736                       Status update unavailable      NaN
# 348737                       Status update unavailable      NaN
# 348738                       Status update unavailable      NaN
# 348739   Investigation complete; no suspect identified      NaN
# 348740   Investigation complete; no suspect identified      NaN
# ...                                                ...      ...
# 1173195                                            NaN      NaN
# 1173196                                            NaN      NaN
# 1173197                                            NaN      NaN
# 1173198                                            NaN      NaN
# 1173199                                            NaN      NaN
#
#                                  Location type  Season
# 348736                On or near Shopping Area  Spring
# 348737                               On Street  Spring
# 348738                               On Street  Spring
# 348739                    On or near Underpass  Spring
# 348740                    On or near Underpass  Spring
# ...                                        ...     ...
# 1173195  On or near London Underground Station  Spring
# 1173196     On or near Train Station/Tram Stop  Spring
# 1173197     On or near Train Station/Tram Stop  Spring
# 1173198     On or near Train Station/Tram Stop  Spring
# 1173199     On or near Train Station/Tram Stop  Spring
#
# [272939 rows x 14 columns]

# %%
# Create a csv file with the new DataFrame that includes all csvs, the new columns and is filtered for the area of Greater London.
df.to_csv(r'C:\Users\Arne\Documents\TechLabs\TechLabs\Group project\Processed Data\Processed Datadata_location_type_season_added.csv', index=False)
